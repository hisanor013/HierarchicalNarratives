# %% [markdown]
# # Select model

# %%
use_model = "gpt-4-turbo-2024-04-09"

# %%
import numpy as np
import tqdm
import random
import pandas as pd
import json
import glob
import matplotlib.pyplot as plt
import jaconv
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
import networkx as nx
import unicodedata
import tiktoken 
import openai
import datetime
import os
import re

# %% [markdown]
# # Find files

# %%
log_list = glob.glob("log_public/public_separated_*" )
print(log_list)
path = log_list[0]
# Out:
# ['log_public/public_separated_C_api_gpt-4-turbo-2024-04-09_2024-06-17T16_11_06.log']

# %% [markdown]
# # Read lines

# %%
text2hantei = dict()
with open(path, "r") as f:
    lines = f.readlines()

out_info,out_edges = [],[]
num_read = 0
index2sentiment = dict()
error_cnt = 0
for kkk in range(len(lines)):
    data = json.loads(lines[kkk])
    answer = data["answer"]
    answer_type = data["type"]
        
    if answer_type == "A":
        subindex = data["subindex"]
        answer_type += "-" + str(subindex)

    input_text = data["input"]    
    if input_text not in text2hantei:
        text2hantei.update({input_text:1})    
        index = data["index"]    
        try:
            if answer.startswith('```json'):
                # Strip the markdown code block indicators
                answer = answer.strip('```json\\n')
                # Load the inner JSON
                answer_dict = json.loads(answer)

            elif "\n}\n}" in answer:
                answer = answer.replace("\n}\n}","]\n}")
                answer_dict = json.loads(answer)

            else:
                answer_dict = json.loads(answer)
            num_read += 1

            try:
                indicator = answer_dict['指示語の置き換え']
            except:
                indicator = answer_dict['指示語の置き寛げ']

            edges = answer_dict['エッジリスト']
            edges = list(edges)
            for j in range(len(edges)):
                out_edges.append(edges[j])
                out_info.append(index)
        except:
            error_cnt += 1
            
print("Number of error: " + str(error_cnt))
# Out:
# Number of error: 4

# %%
print(len(out_edges))
print(len(out_info))
# Out:
# 28337
# 28337

# %% [markdown]
# # Parser

# %%
def parse_pattern(text):
    # テキストからカンマとカッコを用いて大まかなパターンを識別
    # パターン1: "誰が, (何が・誰が, 何に対して, どういう状況を引き起こしているか), (何に対して, どうあるべきである)"
    # パターン2: "誰が, 何に対して, どうあるべきである"
    # パターン3: "誰が, (何が・誰が, 何に対して, どういう状況を引き起こしているか), どうあるべきである"
    # パターン4: "誰が, 何に対し, (誰に対して, どうして欲しい)"

    result = []
    if text.count("(") > 1:

        # カッコを考慮しながら分割
        parts = re.split(r', (?!\s*[^()]*\))', text)
        
        for part in parts:
            # カッコ内の内容をさらに分解
            if '(' in part and ')' not in part:
                result.append(part.split("(")[1])
            elif ')' in part and '(' not in part:
                result.append(part.split("(")[0])

            else:
                result.append(part.strip())
                
    else:
        parts = text.split(",")
        for part in parts:   
            # カッコ内の内容をさらに分解
            if '(' in part and ')' not in part:
                result.append(part.split("(")[1])
            elif ')' in part and '(' not in part:
                result.append(part.split("(")[0])
            else:
                result.append(part.strip())
            
    return result

# %%
out_edges
# Out:
# ['Pattern1 (筆者, AIによる画像生成のデータセットの公開, 義務付ける必要がある)',
#  'Pattern1 (筆者, AIによる画像生成に利用するデータセットの作成, 作品の作成者、著作権者あるいは著作者からの事前の了解と、データセットの利用料の継続的な支払いが必要である)',
#  'Pattern1 (筆者, 画像生成AIの許諾不要な状態, 許容しないこと)',
#  'Pattern3 (画像生成AIの許諾不要な状態, 作品の作成者、著作権者ならびに著作者の利益と機会, 平等を著しく毀損している)',
#  'Pattern3 (作品の無断使用, 後発の漫画家、イラストレーター、アニメーターの労働意欲と創作意欲, 著しく低下させる可能性がある)',
#  'Pattern5 (筆者, (画像生成AIの許諾不要な状態, 作品の作成者、著作権者ならびに著作者の利益と機会, 平等を著しく毀損している), (画像生成AIの許諾不要な状態, 許容しないこと))',
#  'Pattern5 (筆者, (作品の無断使用, 後発の漫画家、イラストレーター、アニメーターの労働意欲と創作意欲, 著しく低下させる可能性がある), (画像生成AIの許諾不要な状態, 許容しないこと))',
#  'Pattern1 (筆者, 生成AI規制法, 作成されるべきである)',
#  'Pattern1 (筆者, 生成AIと人間, 分けて考えるべきである)',
#  'Pattern1 (筆者, 生成AI, 物量と再現性が人間を凌駕している状況である)',
#  'Pattern1 (筆者, 生成AI, 植物のように眠ったままで自我は生まれないため道具である)',
#  'Pattern1 (筆者, 生成AIに著作権, 不要である)',
#  'Pattern1 (筆者, 生成AI規制法, 学習まではOKでそのままネット等に発表はNG＋免許制であるべきである)',
#  'Pattern1 (筆者, 生成AI規制法, 著作権と両立可能である)',
#  'Pattern1 (筆者, 生成AI規制法, 粘り強く対策するべきである)',
#  'Pattern1 (筆者, 特別に著作権を無視できる場合, 明確であるべきである)',
#  'Pattern1 (筆者, 生成AIに関する基本的著作権派, 無視して良いと解釈されている)',
#  'Pattern1 (筆者, 現状の法的対応, 司法に丸投げであるべきではない)',
#  'Pattern1 (筆者, 日本の規制状況, 海外に比べて進んでいるべきである)',
#  'Pattern3 (生成AI, 各種コンテンツ業界, 汚染している)',
#  'Pattern3 (生成AI, 日本の職, 奪っている)',
#  'Pattern3 (生成AI, 日本の経済, 低迷させている)',
#  'Pattern3 (生成AI, 日本の少子化, 加速させている)',
#  'Pattern3 (生成AI, 日本, 滅びさせている)',
#  'Pattern2 (筆者, 日本政府, 日本を助けるようにして欲しい)',
#  'Pattern5 (筆者, (生成AI, 日本の経済, 低迷させている), (日本政府, 日本を助けるようにして欲しい))',
#  'Pattern4 (赤松議員, 生成AIを使った被害, 起きていないと認識されている)',
#  'Pattern3 (生成AI, 世界, 自殺者を出してしまっている状況を引き起こしている)',
#  'Pattern4 (筆者, 学習無制限の生成AI, 日本が誇る貴重なコンテンツを無償で他に明け渡す行為になると捉えている)',
#  'Pattern4 (筆者, 「AIで日本はチャンスをつかむ」という発言, 具体的なプランが知りたいと捉えている)',
#  'Pattern4 (筆者, 生成AIが登場してからの一年間, どのような成果・メリットがあったのか例を挙げてほしいと捉えている)',
#  'Pattern2 (筆者, クリエイター, 意見を真摯に受け止めること)',
#  'Pattern2 (筆者, 日本国内, 世界情勢に合わせた規制を求める)',
#  'Pattern5 (筆者, (生成AI, 世界, 自殺者を出してしまっている状況を引き起こしている), (赤松議員, 生成AIを使った被害, 起きていないと認識されている))',
#  'Pattern5 (筆者, (学習無制限の生成AI, 日本が誇る貴重なコンテンツを無償で他に明け渡す行為になると捉えている), (日本国内, 世界情勢に合わせた規制を求める))',
#  'Pattern5 (筆者, (「AIで日本はチャンスをつかむ」という発言, 具体的なプランが知りたいと捉えている), (日本国内, 世界情勢に合わせた規制を求める))',
#  'Pattern5 (筆者, (生成AIが登場してからの一年間, どのような成果・メリットがあったのか例を挙げてほしいと捉えている), (日本国内, 世界情勢に合わせた規制を求める))',
#  'Pattern4 (筆者, 生成AIの出力した画像が作風等を模倣している場合, 著作権法上の侵害にならないという点について)',
#  'Pattern4 (筆者, 生成AIの出力した画像が作風等を模倣している場合, クリエイター・イラストレーター内での認識と齟齬があり)',
#  'Pattern1 (筆者, 著作権法, 柔軟な改訂が求められる)',
#  'Pattern1 (筆者, 作風の模倣と創作的表現の基準, 速やかにかつ極めて厳格に具体的に定めることが急務である)',
#  'Pattern3 (生成AIユーザーとクリエイターの間の大きな論争, 日本のクリエイティビティ, 衰退させ損なっている)',
#  'Pattern4 (筆者, クリエイター, 生成AIを利用していないことを求められる)',
#  'Pattern4 (筆者, クリエイター, 犯人探しの様相を呈している)',
#  'Pattern2 (筆者, 政府, 著作権と生成AIの利用について周知を徹底すること)',
#  'Pattern4 (筆者, (作風の模倣は著作権侵害にあたらないという指摘, 著作者人格権等について, どのように解釈されるか))',
#  'Pattern4 (筆者, (作品Bを学習して生成された作品C, 著作権および著作者人格権, 侵害しないとされるか))',
#  'Pattern2 (筆者, 法整備もしくは政府広報, 生成AIの学習に利用されることを拒否する簡単な方法を設定して欲しい)',
#  'Pattern3 (生成AIの学習に利用されたくないクリエイター, その手段がないこと, モチベーションが下がることで日本全体のクリエイティビティの損失を引き起こしている)',
#  'Pattern2 (筆者, 法整備もしくは政府広報, ウォーターマークを設定する等の簡便なAI学習拒否の仕組みを作って欲しい)',
#  'Pattern5 (筆者, (生成AIの出力した画像が作風等を模倣している場合, 著作権法上の侵害にならないという点について), (著作権法, 柔軟な改訂が求められる))',
#  'Pattern5 (筆者, (生成AIの出力した画像が作風等を模倣している場合, クリエイター・イラストレーター内での認識と齟齬があり), (作風の模倣と創作的表現の基準, 速やかにかつ極めて厳格に具体的に定めることが急務である))',
#  'Pattern5 (筆者, (生成AIユーザーとクリエイターの間の大きな論争, 日本のクリエイティビティ, 衰退させ損なっている), (政府, 著作権と生成AIの利用について周知を徹底すること))',
#  'Pattern5 (筆者, (生成AIの学習に利用されたくないクリエイター, その手段がないこと, モチベーションが下がることで日本全体のクリエイティビティの損失を引き起こしている), (法整備もしくは政府広報, ウォーターマークを設定する等の簡便なAI学習拒否の仕組みを作って欲しい))',
#  'Pattern3 (反AIと呼ばれる方々, 生成AI利用者, 犯罪者とのレッテル張り等を行っている)',
#  'Pattern3 (サービスの利用者と他のイラスト作成者, とあるサービス上のイラスト案件にてＡＩの一部利用が問題ないということを確認して進めたサービス, 反発の声が上がり、制作物の使用取り下げ及びその後の生成ＡＩ使用禁止に至った)',
#  'Pattern3 (プラットフォーム, ＡＩ利用者, 委縮、また締め出し等の排斥行動が強く行われている)',
#  'Pattern2 (筆者, 関係者, ４．関係者からの様々な懸念の声についてについての意見を周知、啓蒙を一層進めて欲しい)',
#  'Pattern1 (筆者, 出力物における著作権侵害が無い場合のＡＩ利用, 問題ない)',
#  'Pattern5 (筆者, (反AIと呼ばれる方々, 生成AI利用者, 犯罪者とのレッテル張り等を行っている), (関係者, 様々な懸念の声についての意見を周知、啓蒙を一層進めて欲しい))',
#  'Pattern5 (筆者, (サービスの利用者と他のイラスト作成者, とあるサービス上のイラスト案件にてAIの一部利用が問題ないということを確認して進めたサービス, 反発の声が上がり、制作物の使用取り下げ及びその後の生成AI使用禁止に至った), (関係者, 様々な懸念の声についての意見を周知、啓蒙を一層進めて欲しい))',
#  'Pattern5 (筆者, (プラットフォーム, AI利用者, 委縮、また締め出し等の排斥行動が強く行われている), (関係者, 様々な懸念の声についての意見を周知、啓蒙を一層進めて欲しい))',
#  'Pattern3 (報道機関を含む権利者による解釈, AI開発, 強い抑制効果をもたらしている)',
#  'Pattern3 (報道機関を含む権利者による解釈, 国産AIの開発, 萎縮させ頓挫する可能性がある)',
#  'Pattern1 (筆者, 法第30条の4の意味, 無いものであるべきではない)',
#  'Pattern1 (筆者, 日本の発展, 妨げられるべきではない)',
#  'Pattern2 (筆者, 権利者, AI開発者からの意見に耳を傾けること)',
#  'Pattern4 (筆者, 日本の未来, 真剣に考えるべきである)',
#  'Pattern1 (筆者, AI技術, 将来の国民を支えるための国の未来に必要な技術である)',
#  'Pattern5 (筆者, (報道機関を含む権利者による解釈, AI開発, 強い抑制効果をもたらしている), (法第30条の4の意味, 無いものであるべきではない))',
#  'Pattern5 (筆者, (報道機関を含む権利者による解釈, 国産AIの開発, 萎縮させ頓挫する可能性がある), (日本の発展, 妨げられるべきではない))',
#  'Pattern5 (筆者, (日本の未来, 真剣に考えるべきである), (権利者, AI開発者からの意見に耳を傾けること))',
#  'Pattern1 (筆者, 人間に許される行為, AIにも許されるべきである)',
#  'Pattern1 (筆者, 特定の職業の収入を制限の理由, すべきではない)',
#  'Pattern3 (人間とAIとの差, 人間とAI, 曖昧である)',
#  'Pattern3 (人間の脳の一部が損傷し人工臓器で置き換えた場合, 人間とAI, 不明である)',
#  'Pattern3 (将棋の高速読み, 人間, AI以上の速度である場合がある)',
#  'Pattern4 (筆者, (人間とAIとの差, 人間とAI, 曖昧である), 不可能であると捉えている)',
#  'Pattern3 (日本語ワープロの登場, 日本語タイピストの職, 奪った)',
#  'Pattern3 (自動運転の実現, タクシー運転手の職, 奪うことになるかもしれない)',
#  'Pattern3 (AIの登場, 職業, 縮小される)',
#  'Pattern3 (機械化, 真に創造的なもの, 価値が認められる)',
#  'Pattern3 (類似品の増加, 大量生産の粗悪品, 価値が縮小されるかもしれない)',
#  'Pattern4 (筆者, (クリエーターの収入が減ること, 制限の理由, 合理的ではない), 合理的ではないと捉えている)',
#  'Pattern5 (筆者, (人間とAIとの差, 人間とAI, 曖昧である), (人間に許される行為, AIにも許されるべきである))',
#  'Pattern5 (筆者, (日本語ワープロの登場, 日本語タイピストの職, 奪った), (特定の職業の収入を制限の理由, すべきではない))',
#  'Pattern1 (筆者, AIにおいての学び（すなわちデータのインプットとその処理蓄積）を著作権で制限すること, コンピューターサイエンスの発展を妨げることとなる)',
#  'Pattern4 (筆者, AIにおいての学び（すなわちデータのインプットとその処理蓄積）を著作権で制限すること, 人間の学びと何が違うのかという観点で考察を行った際の差異があまりないように思われる)',
#  'Pattern1 (筆者, 人間も誰かの作品から学ぶこと, 著作権において違法であるといえなくもないはずである)',
#  'Pattern4 (筆者, AIは道具にすぎず、AIを使って何かを生成した人間なり法人がそれを公に出したときにはじめて著作物と認められ、著作権の観点での類似などが検討されるべきという現在の文化庁の解釈, 著作権の観点での類似などが検討されるべきと考える)',
#  'Pattern1 (筆者, AIにおいての学びと出力が著作権法に違反するのであれば, AIにも人としての格を法的に与えるべきである)',
#  'Pattern3 (AI, 人間の将棋, レベルが上がっている)',
#  'Pattern1 (筆者, AIの活用, 文化的な作品においても同様であるべきである)',
#  'Pattern5 (筆者, (AIにおいての学び（すなわちデータのインプットとその処理蓄積）を著作権で制限すること, 人間の学びと何が違うのかという観点で考察を行った際の差異があまりないように思われる), (コンピューターサイエンスの発展, 妨げることとなる))',
#  'Pattern5 (筆者, (AIにおいての学びと出力が著作権法に違反するのであれば, 人間の将棋のレベルが上がっている), (AI, 人としての格を法的に与えるべきである))',
#  'Pattern3 (著作権法「第30条の4」の規定, 著作権者, 機械学習の対価を支払う必要はないという考えを助長させている)',
#  'Pattern3 (著作権法「第30条の4」の規定が著作権者に機械学習の対価を支払う必要はないという考えを助長させている状況, クリエイター等のウェルネス, 悪化させている)',
#  'Pattern3 (著作権法「第30条の4」の規定が著作権者に機械学習の対価を支払う必要はないという考えを助長させている状況, 良質なコンテンツの生産, 打撃を与えている)',
#  'Pattern1 (筆者, AIの学習には著作権者の許諾を必要とする法改正, 決断を下していただきたい)',
#  'Pattern5 (筆者, (著作権法「第30条の4」の規定が著作権者に機械学習の対価を支払う必要はないという考えを助長させている状況, クリエイター等のウェルネスを悪化させる), (AIの学習には著作権者の許諾を必要とする法改正, 決断を下していただきたい))',
#  'Pattern3 (AI 学習のための著作物の複製等を防止する技術的な措置, 法第30の4による権利制限, 形骸化してしまう状況を引き起こしている)',
#  'Pattern4 (筆者, (将来販売される資料, 権利制限の対象, ならないと推認される状況))',
#  'Pattern1 (筆者, 我が国のAI学習, 多大なる負の影響を及ぼすべきではない)',
#  'Pattern4 (筆者, 我が国に拠点を設けようとしているAI系のビッグテック, 大抵の学習が合法であると捉えている)',
#  'Pattern1 (筆者, 我が国のアドバンテージ, 失われるべきではない)',
#  'Pattern4 (筆者, この文言, 削除がよいのではないかと考えている)',
#  'Pattern5 (筆者, (AI 学習のための著作物の複製等を防止する技術的な措置, 法第30の4による権利制限, 形骸化してしまう状況を引き起こしている), (我が国のAI学習, 多大なる負の影響を及ぼすべきではない))',
#  'Pattern5 (筆者, (将来販売される資料, 権利制限の対象, ならないと推認される状況), (我が国のAI学習, 多大なる負の影響を及ぼすべきではない))',
#  'Pattern5 (筆者, (AI 学習のための著作物の複製等を防止する技術的な措置, 法第30の4による権利制限, 形骸化してしまう状況を引き起こしている), (我が国のアドバンテージ, 失われるべきではない))',
#  'Pattern5 (筆者, (我が国に拠点を設けようとしているAI系のビッグテック, 大抵の学習が合法であると捉えている), (我が国のアドバンテージ, 失われるべきではない))',
#  'Pattern5 (筆者, (権利制限の対象とはならないと推認される状況に関する文言, 削除がよいのではないかと考えている), (我が国のAI学習, 多大なる負の影響を及ぼすべきではない))',
#  'Pattern1 (筆者, 海賊版サイトなど違法な学習元からの学習行為, 違法にするべき)',
#  'Pattern3 (海賊版サイトなどの違法サイトや違法データからの学習, AI制作者, 氾濫するおそれがある)',
#  'Pattern1 (AI制作者, 学習元の公開, 必須にするべき)',
#  'Pattern5 (筆者, (海賊版サイトなどの違法サイトや違法データからの学習, AI制作者, 氾濫するおそれがある), (海賊版サイトなど違法な学習元からの学習行為, 違法にするべき))',
#  'Pattern5 (筆者, (海賊版サイトなどの違法サイトや違法データからの学習, AI制作者, 氾濫するおそれがある), (AI制作者, 学習元の公開, 必須にするべき))',
#  'Pattern1 (筆者, 生成AIの活用, 基本的に推進していくべきである)',
#  'Pattern4 (筆者, 文章生成系のAI, 効率よく使用すれば企画職や事務職の作業効率を大幅に改善できる)',
#  'Pattern3 (文章生成系のAI, 日本の労働人口不足の解消や生産性向上, 大きく寄与する可能性がある)',
#  'Pattern4 (筆者, 画像・音楽・動画などの生成系AI, 今後より技術的に発展すればクリエイティブの現場の生産性を改善する可能性があると感じる)',
#  'Pattern3 (画像生成AI, 絵が描けなかった人がクリエイティブを始める, 事例もある)',
#  'Pattern4 (筆者, コンテンツの作り手が増えること, プラスに働くと考える)',
#  'Pattern1 (筆者, 生成AIの活用, 推進していくべきである)',
#  'Pattern1 (筆者, AIへの著作物の学習, 容認していく方向性である)',
#  'Pattern1 (筆者, 既存のクリエイターの権利, 保護されるべきである)',
#  'Pattern4 (筆者, 明確に「似せる」意思を持って作られた学習データ, 非常にお行儀が悪い)',
#  'Pattern2 (筆者, 国, 利用のガイドラインを明確に定め、容認できるライン、許容されないラインをより具体的に示して欲しい)',
#  'Pattern3 (一度生まれてしまった技術, 日本社会, なくすことはできない状況を引き起こしている)',
#  'Pattern2 (筆者, 日本社会, 生成AIを上手く浸透させ、労働環境の改善や生産性向上に寄与するような施策を求める)',
#  'Pattern5 (筆者, (文章生成系のAI, 日本の労働人口不足の解消や生産性向上を大きく寄与する可能性がある), (生成AIの活用, 基本的に推進していくべきである))',
#  'Pattern5 (筆者, (画像生成AI, 絵が描けなかった人がクリエイティブを始める事例もある), (生成AIの活用, 推進していくべきである))',
#  'Pattern5 (筆者, (一度生まれてしまった技術, 日本社会になくすことはできない状況を引き起こしている), (日本社会, 生成AIを上手く浸透させ、労働環境の改善や生産性向上に寄与するような施策を求める))',
#  'Pattern2 (筆者, 生成AI, 侵害の可能性があるものを容易には作成できぬようにすることを求める)',
#  'Pattern2 (筆者, 事業者, 侵害の可能性を警告することを求める)',
#  'Pattern2 (筆者, 事業者, 警告の表示を義務付けることを求める)',
#  'Pattern1 (筆者, 侵害の行為を組成した物又は侵害の行為によって作成された物, 何かしらの請求を行えるようであるべき)',
#  'Pattern1 (筆者, 生成AIに何らかの制限を設けること、事業者に対して侵害の可能性を警告すること、又は事業者に対して警告の表示を義務付けること, 軽度の請求も想定されるべき)',
#  'Pattern4 (筆者, 全般的な提案, 侵害に対する措置について賛同している)',
#  'Pattern3 (生成AIによる学習, 人間が行う学習, 遥かに高速・膨大である)',
#  'Pattern1 (筆者, 生成AIによる著作権の判断基準・運用, 人対人で想定される著作権と異なるであるべき)',
#  'Pattern5 (筆者, (生成AIによる学習, 人間が行う学習, 遥かに高速・膨大である), (生成AI, 侵害の可能性があるものを容易には作成できぬようにすることを求める))',
#  'Pattern5 (筆者, (生成AIによる学習, 人間が行う学習, 遥かに高速・膨大である), (事業者, 侵害の可能性を警告することを求める))',
#  'Pattern5 (筆者, (生成AIによる学習, 人間が行う学習, 遥かに高速・膨大である), (事業者, 警告の表示を義務付けることを求める))',
#  'Pattern5 (筆者, (全般的な提案, 侵害に対する措置について賛同している), (生成AI, 侵害の可能性があるものを容易には作成できぬようにすることを求める))',
#  'Pattern5 (筆者, (全般的な提案, 侵害に対する措置について賛同している), (事業者, 侵害の可能性を警告することを求める))',
#  'Pattern5 (筆者, (全般的な提案, 侵害に対する措置について賛同している), (事業者, 警告の表示を義務付けることを求める))',
#  'Pattern1 (筆者, 生成AI, 全面的に禁止であるべき)',
#  'Pattern3 (生成AI, クリエイター, 心が折れる状況を引き起こしている)',
#  'Pattern3 (生成AI, 創作文化, 発展が止まる状況を引き起こしている)',
#  'Pattern3 (生成AI, 社会, 混乱する状況を引き起こしている)',
#  'Pattern2 (筆者, 読者, 生成AIを全面的に禁止することを求める)',
#  'Pattern5 (筆者, (生成AI, 社会, 混乱する状況を引き起こしている), (読者, 生成AIを全面的に禁止することを求める))',
#  'Pattern1 (筆者, 生成AIの出力物をコンテンツとして公開すること, 禁止すべきである)',
#  'Pattern1 (筆者, 生成AIからの出力物, 犯罪である)',
#  'Pattern2 (文化庁, 政府, 生成AIセミナーを開くことを求める)',
#  'Pattern4 (文化庁, (剽窃AI犯罪企業, 生成AIセミナーを開けという命令に従い, 犯罪者だと宣言しなかったこと), 嘘を吹聴したくなかったがために)',
#  'Pattern3 (剽窃AI犯罪企業, 日本, 酷い盗作国家となる状況を引き起こしている)',
#  'Pattern4 (筆者, 文化庁, 文化破壊庁である)',
#  'Pattern1 (筆者, 生成AIからの出力物, 著作物ではない)',
#  'Pattern1 (筆者, 人間が作った著作物を利用されたデータセット, 複製物である)',
#  'Pattern3 (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている)',
#  'Pattern3 (生成AIサービスの会社, 犯罪行為, 利用者に責任を擦り付けている状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), 直接犯罪を行っていないと捉えている)',
#  'Pattern3 (生成AI, コンテンツの公開, 犯罪者として処罰される状況を引き起こしている)',
#  'Pattern3 (生成AIで出力したものを手描きとして売る行為, 財物の交付, 詐欺罪に該当する状況を引き起こしている)',
#  'Pattern3 (スクレイピングによる学習データを利用した生成AI, コンテンツの公開, 著作権法違反の状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AI, コンテンツの公開, 犯罪者として処罰される状況を引き起こしている), 犯罪になるはずである)',
#  'Pattern3 (生成AI, 著作権法, 罪が加算される状況を引き起こしている)',
#  'Pattern3 (生成AIの登場, 世界的な悪用, 行われる状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIの規制, 喫緊の課題である)',
#  'Pattern3 (警察, 児童や学生と思われるポルノ画像の生成と公開, 捕まえることが可能である状況を引き起こしているか)',
#  'Pattern3 (児童ポルノ製造等罪, 無償提供, 罪に問われる状況を引き起こしているか)',
#  'Pattern3 (ネットでの送信, 児童ポルノ, 5年以下の懲役または500万円以下の罰金という罰則を引き起こしているか)',
#  'Pattern3 (リアルな３DCG, 現在の判例, 罪に問われない状況を引き起こしているか)',
#  'Pattern4 (筆者, Stable Diffusionの画像生成AIシステム, 画像生成AIにはマジモンの児童ポルノの写真が入っていますので有罪になるという見解)',
#  'Pattern3 (Stable Diffusionの画像生成AIシステム, PCでの所持, 児童ポルノ単純所持罪ならびに製造罪が適用される状況を引き起こしている)',
#  'Pattern4 (筆者, 生成AI利用者, 刑に処してください)',
#  'Pattern5 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), (生成AIの出力物, 禁止すべきである))',
#  'Pattern5 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), (生成AIからの出力物, 犯罪である))',
#  'Pattern5 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), (生成AIからの出力物, 著作物ではない))',
#  'Pattern5 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), (人間が作った著作物を利用されたデータセット, 複製物である))',
#  'Pattern5 (筆者, (生成AIサービスの会社, 盗作の提供, 利用者に対価として提供している状況を引き起こしている), (生成AIの規制, 喫緊の課題である))',
#  'Pattern3 (生成AI, インターネット上の画像や文章音声, 無断で収集し抽出してデータセットとして圧縮している)',
#  'Pattern3 (生成AI, データ, 高度な検索システムで選別し圧縮したデータをもとに復元している)',
#  'Pattern3 (権利者, 生成AIのデータ収集, 意思を完全に無視されている)',
#  'Pattern3 (第三者, 権利者のデータ, 商用利用などを行い利益を得ている)',
#  'Pattern4 (筆者, (生成AI, 権利者のデータ, 搾取している), はっきりと搾取であると感じている)',
#  'Pattern4 (筆者, (生成AI, 元データ, ロンダリングをするシステムであると思っている), ロンダリングをするシステムだと思っている)',
#  'Pattern3 (生成AI, 使用者と権利者, 気が付かないうちにデータを盗用している状況を引き起こしているか)',
#  'Pattern4 (筆者, (生成AI, 著作物に存在するデータ, 際限なく利用されること), 先人の作り上げた文化や芸術、業績を破壊する未来につながっていくと捉えているか)',
#  'Pattern1 (筆者, 生成AIがデータを盗用している状況, NOを突きつけるべきである)',
#  'Pattern5 (筆者, (生成AI, インターネット上の画像や文章音声, 無断で収集し抽出してデータセットとして圧縮している), (生成AIがデータを盗用している状況, NOを突きつけるべきである))',
#  'Pattern5 (筆者, (生成AI, データ, 高度な検索システムで選別し圧縮したデータをもとに復元している), (生成AIがデータを盗用している状況, NOを突きつけるべきである))',
#  'Pattern5 (筆者, (生成AI, 使用者と権利者, 気が付かないうちにデータを盗用している状況を引き起こしているか), (生成AIがデータを盗用している状況, NOを突きつけるべきである))',
#  'Pattern3 (生成AI, 著作者の権利, 守れない状況を引き起こしている)',
#  'Pattern3 (規制がある国のAI, AI成長, 鈍化している)',
#  'Pattern1 (筆者, 最悪のシナリオ, 避けるべきである)',
#  'Pattern4 (生成AI, 学習と生成, 速度と誰でもできることという点で異なっている)',
#  'Pattern3 (生成AI, 作品の生成と配布, 速度が上回っている)',
#  'Pattern1 (筆者, 現行法と生成AIの矛盾, 実現実効性に乏しい)',
#  'Pattern1 (筆者, 著作者の権利の侵害, 定義する)',
#  'Pattern3 (AIによる学習自体, 著作者の権利, 何ら侵害するものではない)',
#  'Pattern3 (AIによる学習で得られた学習モデルを使って生成し、生成物を配布すること, 著作者の権利, 侵害する)',
#  'Pattern3 (悪意のある著作権侵害, 作品の配布, 著作物の名前を使って衆目を集め、モデルの利用または侵害した作品の販売などを行う状況を引き起こしている)',
#  'Pattern1 (筆者, 著作物の名前を使用する権利に対して, 保護を強化)',
#  'Pattern1 (筆者, 侵害への罰則, 強化する)',
#  'Pattern3 (著作物の公衆への配布・衆目を集める行為・収益化, 生成AIによる著作権の侵害, 制限することができる)',
#  'Pattern3 (明確な権利侵害についての定義, 法律上, 行えること)',
#  'Pattern3 (類似性や依拠性, 法律上の定義, 考慮しなくてよいこと)',
#  'Pattern3 (明確な権利侵害についての定義, 非親告罪, 取り扱えること)',
#  'Pattern3 (ミッキーマウスを例に取る具体的な法整備, 伏せ字を用いた作品の配布, 規制を行うこと)',
#  'Pattern4 (筆者, 生成AIによる著作権の侵害を国内外問わず明確に行える様になる提案, 生成AI自体を何ら制限するものでは無く、国内のAI技術の遅れにもつながらないため、AI産業の競争力低下につながらないという利点がある)',
#  'Pattern5 (筆者, (生成AI, 著作者の権利, 守れない状況を引き起こしている), (最悪のシナリオ, 避けるべきである))',
#  'Pattern5 (筆者, (生成AI, 学習と生成, 速度と誰でもできることという点で異なっている), (現行法と生成AIの矛盾, 実現実効性に乏しい))',
#  'Pattern5 (筆者, (AIによる学習自体, 著作者の権利, 何ら侵害するものではない), (著作者の権利の侵害, 定義する))',
#  'Pattern5 (筆者, (AIによる学習で得られた学習モデルを使って生成し、生成物を配布すること, 著作者の権利, 侵害する), (著作者の権利の侵害, 定義する))',
#  'Pattern5 (筆者, (悪意のある著作権侵害, 作品の配布, 著作物の名前を使って衆目を集め、モデルの利用または侵害した作品の販売などを行う状況を引き起こしている), (著作物の名前を使用する権利に対して, 保護を強化))',
#  'Pattern5 (筆者, (生成AIによる著作権の侵害を国内外問わず明確に行える様になる提案, 生成AI自体を何ら制限するものでは無く、国内のAI技術の遅れにもつながらないため、AI産業の競争力低下につながらないという利点がある), (侵害への罰則, 強化する))',
#  'Pattern4 (筆者, 生成AIによる無断無償の学習、販売, この世の終わりである)',
#  'Pattern1 (筆者, 生成AIの規制, 喫緊の課題である)',
#  'Pattern2 (筆者, 政府, 法律整備を求める)',
#  'Pattern2 (筆者, 政府, 画像にノイズを付加することでイラスト生成AI学習を攻撃するツールをAI開発・学習のための複製等を防止する技術的な措置として扱うかどうか示して欲しい)',
#  'Pattern2 (筆者, 政府, 画像にノイズを付加することでイラスト生成AI学習を攻撃するツールによって企業等が作成する生成AIに悪影響が生じた場合、業務妨害等の犯罪・違法行為となるかどうか示して欲しい)',
#  'Pattern3 (反AI, 生成AI, 強烈な反対意見を引き起こしている)',
#  'Pattern4 (筆者, (反AI, 生成AI, 強烈な反対意見を引き起こしている))',
#  'Pattern4 (筆者, 反AIの殆どが絵描きであること, 自身の仕事が減ることを恐れたポジショントークでしかない)',
#  'Pattern4 (筆者, 彼らが絵師を守る等を目的としていると自称していること, 建前でしかなく、自分の仕事を減らさないためのポジショントークである)',
#  'Pattern3 (彼ら, 生成AIに賛成的な絵師, 激しい攻撃を行っている)',
#  'Pattern3 (彼ら, 無断学習によって成り立つ機械翻訳等, 当然のように使用している)',
#  'Pattern4 (筆者, 大きな矛盾を孕んだポジショントークである, 頭に入れることを強く推奨する)',
#  'Pattern1 (筆者, AIの更なる発展と効果的な利用, 重要である)',
#  'Pattern5 (筆者, (反AIの人々, 生成AI, 強烈な反対意見を引き起こしている), (政府, 画像にノイズを付加することでイラスト生成AI学習を攻撃するツールをAI開発・学習のための複製等を防止する技術的な措置として扱うかどうか示して欲しい))',
#  'Pattern5 (筆者, (反AIの人々, 生成AI, 強烈な反対意見を引き起こしている), (政府, 画像にノイズを付加することでイラスト生成AI学習を攻撃するツールによって企業等が作成する生成AIに悪影響が生じた場合、業務妨害等の犯罪・違法行為となるかどうか示して欲しい))',
#  'Pattern3 (AI, 私たちの日常生活, ますます重要な役割を果たしている)',
#  'Pattern4 (筆者, AIが違法行為に使用された場合の責任, 公正ではない)',
#  'Pattern3 (AIが違法化され、その責任が親告罪として個人に帰属する場合, 多くの人々, 不当な負担を強いられるおそれがある)',
#  'Pattern3 (AIを開発した企業や個人, 訴訟を起こすため, 証拠を収集し、裁判を進めるための費用や時間が必要となる)',
#  'Pattern3 (AIが違法化され、その責任が親告罪として個人に帰属する場合の結果, 一部の個人や企業, 訴訟を起こす余裕がある)',
#  'Pattern3 (AIが違法化され、その責任が親告罪として個人に帰属する場合の結果, 多くの被害者, 救済を受けることができないかもしれない)',
#  'Pattern1 (筆者, AIの違法行為に関与した際の責任, 均等に分担されるべきである)',
#  'Pattern1 (関連企業や機関, 適切な対策, 講じる責任を持つべきである)',
#  'Pattern2 (筆者, 被害者, 訴訟を起こす主体となる)',
#  'Pattern2 (筆者, 法制度, AIの違法行為に関する法律が議論された際に被害者の権利を保護し公正な制度を確立するよう強く働きかける)',
#  'Pattern1 (筆者, 法的なフレームワーク, 作り上げ適切な責任割当を行うことで公平かつ効果的な対策を講じるべきである)',
#  'Pattern5 (筆者, (AIが違法行為に使用された場合の責任, 公正ではない), (AIの違法行為に関する法律が議論された際, 被害者の権利を保護し公正な制度を確立するよう強く働きかける))',
#  'Pattern5 (筆者, (AIが違法化され、その責任が親告罪として個人に帰属する場合, 多くの人々, 不当な負担を強いられるおそれがある), (AIの違法行為に関する法律が議論された際, 被害者の権利を保護し公正な制度を確立するよう強く働きかける))',
#  'Pattern3 (AI生成物, 特定のクリエイターや著作物の需要, 代替してしまうような事態を引き起こしている)',
#  'Pattern3 (特定の著作者の著作物の情報解析, 特定の著作者の将来的な名誉声望, 喪失させるおそれがある)',
#  'Pattern4 (筆者, (生成AI, 既存の表現, ありふれた表現化させることができる))',
#  'Pattern3 (特定の著作者の著作物の利用, 特定の著作者の現在の社会的な名誉声望, 害する方法である)',
#  'Pattern1 (筆者, 生成AIによる学習, 元の画像や文章、音声に類似、またはほぼ同一のものが出力される現在の状況において、元の権利者の当然得られたであろう金銭的収入、社会的地位、名誉を傷つける可能性がある学習を拒否する権利が必要である)',
#  'Pattern1 (筆者, 学習においてはその内容の出典をすべて明らかにすること, 求める)',
#  'Pattern1 (筆者, 学習において著作権者、被写体などの権利者の許可が得られない場合, 勝手に利用できないものとすべきである)',
#  'Pattern1 (筆者, 生成されたもの, 生成AI製であることを明示することを求める)',
#  'Pattern3 (生成AIで作成されたデータ, 実際の戦争や災害の画像などとして発表された結果, 報道を混乱させる)',
#  'Pattern3 (生成AIで作成されたデータ, 著名人、あるいは身近な人間になりすまし, 犯罪行為や倫理にもとる行動をとらせて名誉を傷つけたり、詐欺に使われる例がみられる)',
#  'Pattern1 (筆者, 生成AIとそうでないもの, 明らかに分別可能であるようにすべきである)',
#  'Pattern1 (筆者, 生成されたものが違法である場合の生成者, 責任があるとすべきである)',
#  'Pattern4 (筆者, 生成AIによって作り出されたデータの著作物性, ないと考える)',
#  'Pattern3 (生成AIによって作り出されたデータの表現, 学習元, 依拠している)',
#  'Pattern4 (筆者, 生成AIによって作り出されたデータの表現, 同じ文言を使えば全く別の人間であっても同じ表現が可能である)',
#  'Pattern5 (筆者, (生成AIで作成されたデータ, 実際の戦争や災害の画像などとして発表された結果, 報道を混乱させる), (生成されたもの, 生成AI製であることを明示することを求める))',
#  'Pattern5 (筆者, (生成AIで作成されたデータ, 著名人、あるいは身近な人間になりすまし, 犯罪行為や倫理にもとる行動をとらせて名誉を傷つけたり、詐欺に使われる例がみられる), (生成されたものが違法である場合の生成者, 責任があるとすべきである))',
#  'Pattern1 (筆者, データベースの著作物のみに「非享受目的を本来的利用とする著作物」を限定すること, 不当である)',
#  'Pattern3 (生成AIの追加学習などの技術, 著作物の経済価値, 新たな可能性を生み出している)',
#  'Pattern4 (筆者, イラストの著作物について、情報解析を困難にするノイズを付与したものを享受目的用として公開し、ノイズを付与していないものを非享受目的用として販売する場合, 複数の考え方が存在する)',
#  'Pattern4 (筆者, (第三者, 享受目的と非享受目的いずれかを本来的利用とする一つの著作物, どちらが本来的利用かを決定している))',
#  'Pattern1 (筆者, 非享受目的を本来的利用とする著作物の枠組み, 検討するべきである)',
#  'Pattern5 (筆者, (生成AIの追加学習などの技術, 著作物の経済価値, 新たな可能性を生み出している), (データベースの著作物のみに「非享受目的を本来的利用とする著作物」を限定すること, 不当である))',
#  'Pattern5 (筆者, (イラストの著作物について、情報解析を困難にするノイズを付与したものを享受目的用として公開し、ノイズを付与していないものを非享受目的用として販売する場合, 複数の考え方が存在する), (非享受目的を本来的利用とする著作物の枠組み, 検討するべきである))',
#  'Pattern3 (生成AI, 著作権問題, 学習と生成のスパンの速さから問題視されている状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AI, 著作権問題, 学習と生成のスパンの速さから問題視されている状況を引き起こしている))',
#  'Pattern1 (筆者, 日本のクリエイターを守る方向, クールジャパン政策に合致する喫緊の課題である)',
#  'Pattern4 (筆者, 生成AIに対する嫌悪的なユーザー, 感情的な部分が多いと捉えている)',
#  'Pattern3 (生成AI, 創作者, 創作者側が自分たちの仕事を失うのではという点を問題視している)',
#  'Pattern3 (生成AI, 著作権, 絵柄のコピー製品に近い生成AIの著作権問題を引き起こしている)',
#  'Pattern4 (筆者, (生成AI, 創作者, 創作者側が自分たちの仕事を失うのではという点を問題視している))',
#  'Pattern4 (筆者, (生成AI, 著作権, 絵柄のコピー製品に近い生成AIの著作権問題を引き起こしている))',
#  'Pattern4 (筆者, 感情的な部分と著作権にふれる部分と利便性が混ざった生成AIの問題, 重要な問題である)',
#  'Pattern1 (筆者, 生成AIの規制, 既存の創作者と著作権的に問題ない状態にする方向に勧めるべきである)',
#  'Pattern4 (筆者, 既存の創作者と著作権的に問題ない状態にする方向, 日本の強みになり得る)',
#  'Pattern5 (筆者, (生成AI, 創作者, 創作者側が自分たちの仕事を失うのではという点を問題視している), (生成AIの規制, 既存の創作者と著作権的に問題ない状態にする方向に勧めるべきである))',
#  'Pattern5 (筆者, (生成AI, 著作権, 絵柄のコピー製品に近い生成AIの著作権問題を引き起こしている), (生成AIの規制, 既存の創作者と著作権的に問題ない状態にする方向に勧めるべきである))',
#  'Pattern3 (生成AI, 特定のイラストレーター等, 嫌がらせをしようとする連中の存在を引き起こしている)',
#  'Pattern3 (ロシア軍, ゼレンスキー大統領, 虚偽の発言をさせる動画を発信している)',
#  'Pattern1 (筆者, 法整備, きちんとすべきである)',
#  'Pattern5 (筆者, (生成AI, 特定のイラストレーター等, 嫌がらせをしようとする連中の存在を引き起こしている), (法整備, きちんとすべきである))',
#  'Pattern5 (筆者, (ロシア軍, ゼレンスキー大統領, 虚偽の発言をさせる動画を発信している), (法整備, きちんとすべきである))',
#  'Pattern1 (筆者, 生成AIイラスト, 窃盗である)',
#  'Pattern3 (生成AI, イラストの絵柄, 無許可で学習している状況を引き起こしている)',
#  'Pattern4 (筆者, イラストの絵柄, その人が人生をかけて作り上げてきた財産である)',
#  'Pattern3 (絵描き, デジタルツールを使用したイラスト作成, 最低6時間かけて1枚のイラストを描き上げている状況を引き起こしている)',
#  'Pattern1 (筆者, 世の中, 努力が報われるようであるべきである)',
#  'Pattern2 (筆者, インボイスでダメージを受けたイラストレーター, 生成AIに寛容な世の中にして追い討ちをかけないで欲しい)',
#  'Pattern1 (筆者, 海外から愛される日本の文化を支える人たち, 大事にされるべきである)',
#  'Pattern5 (筆者, (生成AI, イラストの絵柄, 無許可で学習している状況を引き起こしている), (生成AIイラスト, 窃盗である))',
#  'Pattern5 (筆者, (イラストの絵柄, その人が人生をかけて作り上げてきた財産である), (生成AIイラスト, 窃盗である))',
#  'Pattern5 (筆者, (絵描き, デジタルツールを使用したイラスト作成, 最低6時間かけて1枚のイラストを描き上げている状況を引き起こしている), (世の中, 努力が報われるようであるべきである))',
#  'Pattern5 (筆者, (生成AI, イラストの絵柄, 無許可で学習している状況を引き起こしている), (インボイスでダメージを受けたイラストレーター, 生成AIに寛容な世の中にして追い討ちをかけないで欲しい))',
#  'Pattern5 (筆者, (イラストの絵柄, その人が人生をかけて作り上げてきた財産である), (インボイスでダメージを受けたイラストレーター, 生成AIに寛容な世の中にして追い討ちをかけないで欲しい))',
#  'Pattern5 (筆者, (絵描き, デジタルツールを使用したイラスト作成, 最低6時間かけて1枚のイラストを描き上げている状況を引き起こしている), (インボイスでダメージを受けたイラストレーター, 生成AIに寛容な世の中にして追い討ちをかけないで欲しい))',
#  'Pattern5 (筆者, (生成AI, イラストの絵柄, 無許可で学習している状況を引き起こしている), (海外から愛される日本の文化を支える人たち, 大事にされるべきである))',
#  'Pattern5 (筆者, (イラストの絵柄, その人が人生をかけて作り上げてきた財産である), (海外から愛される日本の文化を支える人たち, 大事にされるべきである))',
#  'Pattern3 (生成AI, 著作権法, 適用外に当たる状況を引き起こしている)',
#  'Pattern4 (筆者, 生成AIの商用利用の仕組み, 自然な解釈である)',
#  'Pattern4 (筆者, 生成AIの著作権に関する素案, 著作権が邪魔であると透けて見える)',
#  'Pattern4 (筆者, 生成AIの便益, 注目されている)',
#  'Pattern4 (筆者, 生成AIの猛威, 非常に厄介な技術であるという印象を持っている)',
#  'Pattern3 (生成AI, 著作権ロンダリング, 絵柄の模倣を引き起こしている)',
#  'Pattern2 (筆者, 政府, 「マリオ」などの日本にとってとても大切なコンテンツの価値が極端に侵害されやすい現状に早急に対応してほしい)',
#  'Pattern3 (機械的な模倣, 「マリオ」などの日本にとってとても大切なコンテンツ, 価値を侵害している)',
#  'Pattern3 (機械的な模倣, 文化, 半年以上愛した文化を僭称し、嘲笑わせる現状を引き起こしている)',
#  'Pattern4 (筆者, (機械的な模倣, 文化, 半年以上愛した文化を僭称し、嘲笑わせる現状を引き起こしている), 大変疲弊していると捉えている)',
#  'Pattern4 (筆者, 絵の習得, 理解と尊敬なしにはできないものだと捉えている)',
#  'Pattern3 (絵が嫌いな人, 絵柄, 簡単に絵柄を奪い作者本人にあなたはもういらないと煽る状況を引き起こしている)',
#  'Pattern3 (生成AI利用者, 生成AIが引き起こす精神的ダメージの問題, 啓発している)',
#  'Pattern3 (生成AI, 人の文化, 存在意義を揺るがしている)',
#  'Pattern4 (多くの人, (生成AI, 人の文化, 存在意義を揺るがしている), 生成AIによる文化の存在意義の揺らぎに対する嫌悪感や不安感を拭いえない)',
#  'Pattern4 (筆者, (生成AI, 著作権法, 疑問符が付く), 道義的な理由から推進する意義はない)',
#  'Pattern4 (筆者, 絵の習得, 大変である)',
#  'Pattern3 (鍛錬の過程, 絵を描く文化, 様々な先人の技やアイデアに繋がり尊敬が生まれている)',
#  'Pattern4 (筆者, 文化のある国への愛情, 存在している)',
#  'Pattern4 (筆者, 著作物, 文化とつながることの意義が大切である)',
#  'Pattern2 (筆者, 政府, 著作権者の権利が海賊版や生成AIから守られるような仕組みを作って欲しい)',
#  'Pattern2 (筆者, 政府, 創作を志す若者たちが安心して文化を紡いでいけるような環境の整備をして欲しい)',
#  'Pattern5 (筆者, (生成AI, 著作権法, 適用外に当たる状況を引き起こしている), (政府, 著作権者の権利が海賊版や生成AIから守られるような仕組みを作って欲しい))',
#  'Pattern5 (筆者, (生成AI, 著作権ロンダリング, 絵柄の模倣を引き起こしている), (政府, 「マリオ」などの日本にとってとても大切なコンテンツの価値が極端に侵害されやすい現状に早急に対応してほしい))',
#  'Pattern5 (筆者, (機械的な模倣, 文化, 半年以上愛した文化を僭称し、嘲笑わせる現状を引き起こしている), (政府, 創作を志す若者たちが安心して文化を紡いでいけるような環境の整備をして欲しい))',
#  'Pattern3 (生成AIのデータセット, 著作者の著作物, 模倣した嫌がらせや脅迫を引き起こしている)',
#  'Pattern3 (生成AIのデータセット, 著作者の著作物, 貶めるディープフェイクを引き起こしている)',
#  'Pattern4 (筆者, 生成AIのデータセット, 漫画村と等しいものである)',
#  'Pattern1 (筆者, 生成AIのデータセット, 知的財産権的に問題である)',
#  'Pattern1 (筆者, 無断で学習する行為, 許されてはならない)',
#  'Pattern1 (筆者, 無償でデータを使ったり販売する行為, 許されてはならない)',
#  'Pattern1 (筆者, 著作者・所有者の財産を侵害する行為, 許されてはなりません)',
#  'Pattern1 (筆者, 生成AIの使用を推奨する行為, 法治国家として如何なものであるか疑問である)',
#  'Pattern5 (筆者, (生成AIのデータセット, 著作者の著作物, 模倣した嫌がらせや脅迫を引き起こしている), (生成AIのデータセット, 知的財産権的に問題である))',
#  'Pattern5 (筆者, (生成AIのデータセット, 著作者の著作物, 貶めるディープフェイクを引き起こしている), (生成AIのデータセット, 知的財産権的に問題である))',
#  'Pattern5 (筆者, (生成AIのデータセット, 漫画村と等しいものである), (生成AIのデータセット, 知的財産権的に問題である))',
#  'Pattern2 (筆者, 政府, クリエイターが納得できる方法にして欲しい)',
#  'Pattern2 (筆者, 政府, オプトイン方式にするなどの方法を推進して欲しい)',
#  'Pattern4 (筆者, 政府が推進する方式, クリエイターの権利を無視して踏みにじるような方式である)',
#  'Pattern3 (今のAIでデータ元になったクリエイターへの還元が０の状態, クリエイター, オリジナルの創作をしたいと思わない状況を引き起こしている)',
#  'Pattern3 (データ元になるクリエイターを殺して, データにただ乗りする行為, 健全な活動を破壊する行為を引き起こしている)',
#  'Pattern4 (筆者, ニューヨークタイムスの文章がほぼそのまま出てきたり、映画のワンシーンのほぼ同じものが出てきたりしている状況, 切り貼りではないという主張に対して疑問を持っている)',
#  'Pattern3 (データが高精度になる, 画像, 元データそのままのような画像が出てくる事を増やしている)',
#  'Pattern2 (筆者, 政府, オプトイン方式にして安心して使えるようにするなどの納得できる方法にしてほしい)',
#  'Pattern4 (筆者, 現状のAIのやっていること, 漫画村と似たようなものである)',
#  'Pattern5 (筆者, (現状のAIのやっていること, 漫画村と似たようなものである), (政府, オプトイン方式にして安心して使えるようにするなどの納得できる方法にしてほしい))',
#  'Pattern5 (筆者, (今のAIでデータ元になったクリエイターへの還元が０の状態, クリエイター, オリジナルの創作をしたいと思わない状況を引き起こしている), (政府, クリエイターが納得できる方法にして欲しい))',
#  'Pattern3 (開発者, 生成AI, 利用者を考慮していない状況を引き起こしている)',
#  'Pattern4 (クリエイター, 生成AI, 自身の制作を補助する役目としての利用である)',
#  'Pattern4 (クリエイター, 生成AIが自身の制作を補助する役目として利用される場合, 自身の著作物を取り込む事に躊躇いはない)',
#  'Pattern3 (一般ユーザーやクリエイター, 生成AI, 利用することが可能な状況を引き起こしている)',
#  'Pattern3 (一般ユーザー, 生成AI, 自身の著作物ではない物を取込み出力することが可能な状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIに取り込まれる学習データ, 学習の許可又は明記が必要である)',
#  'Pattern1 (筆者, クリエイターが考える理想的な生成AI, 「クリエイター個人又は企業を補助するための道具」であるべきである)',
#  'Pattern1 (筆者, 学習データを共有せず、個人や企業の閉鎖的なデータ内でのツールとして使用すること, 理想的な利用方法である)',
#  'Pattern2 (筆者, 生成AIを提供する側, 削除を可能とする体制を用意して欲しい)',
#  'Pattern3 (一般ユーザー, クリエイター, 生成AIへの嫌悪感を募らせている)',
#  'Pattern3 (不適切な著作物, クリエイター, 生成AIへの嫌悪感を募らせている)',
#  'Pattern4 (筆者, (一般ユーザー, クリエイター, 生成AIへの嫌悪感を募らせている), 容易に想像がつく)',
#  'Pattern4 (筆者, 生成AIを使用した場合, 自動的に画像内にサイン等を明記する、またはサインをデジタルデータとして埋め込む事である)',
#  'Pattern2 (筆者, クリエイター, 生成AIが有益なツールになるよう改善を求める)',
#  'Pattern5 (筆者, (生成AI, 利用者を考慮していない状況を引き起こしている), (生成AIを提供する側, 削除を可能とする体制を用意して欲しい))',
#  'Pattern5 (筆者, (生成AI, 利用者を考慮していない状況を引き起こしている), (クリエイター, 生成AIが有益なツールになるよう改善を求める))',
#  'Pattern5 (筆者, (一般ユーザーやクリエイター, 生成AI, 利用することが可能な状況を引き起こしている), (生成AIに取り込まれる学習データ, 学習の許可又は明記が必要である))',
#  'Pattern5 (筆者, (一般ユーザー, 生成AI, 自身の著作物ではない物を取込み出力することが可能な状況を引き起こしている), (生成AIに取り込まれる学習データ, 学習の許可又は明記が必要である))',
#  'Pattern2 (筆者, 著作権者, 海賊版等の権利侵害複製物をAI学習のため複製することについて学習しても問題ないとしてほしい)',
#  'Pattern4 (筆者, 生成AIの規制に関する意見, この世の中にあるデータが学習しやすいようになっていないのが悪いのであって、権利侵害であっても学習しやすいようになっているものであれば、学習しても問題ないとしてほしい)',
#  'Pattern4 (筆者, 生成AIの規制に関する意見, あの海賊版サイトであれば容易に読むことができる)',
#  'Pattern4 (筆者, 生成AIの規制に関する意見, その場合があってほしい)',
#  'Pattern4 (筆者, 生成AIの規制に関する意見, プロンプトの内容で依拠性が否定できる場合があってほしい)',
#  'Pattern2 (筆者, AI利用者, AI学習用データに当該著作物が含まれる場合AI利用者と開発者は多くの場合は別だし、学習に使う大量のデータを利用者が把握するのは困難なので、学習データに当該著作物が含まれているから依拠性があると判断されると、AIの利用が困難になるので、やめてほしい)',
#  'Pattern4 (筆者, 生成AIの規制に関する意見, 何らかの基準を超える大量のデータを扱っていれば依拠性はないと判断してほしい)',
#  'Pattern2 (筆者, AIの開発者や運用者, 学習用データを全て保存することをやめてほしい)',
#  'Pattern2 (筆者, 規制当局, 何らかの基準を超える大量のデータを扱っていれば依拠性はないと判断してほしい)',
#  'Pattern2 (筆者, 規制当局, 特定のプロンプト入力については、生成をしないといった措置を推奨しないでほしい)',
#  'Pattern4 (筆者, 特定のプロンプト入力については、生成をしないといった措置, 過剰な対応がされそうである)',
#  'Pattern4 (筆者, 「シネマ」に「シネ」が含まれているので暴言である, 雑な言葉狩りと似たようなことが起こるのではないか)',
#  'Pattern5 (筆者, (世の中にあるデータが学習しやすいようになっていないのが悪い, 権利侵害であっても学習しやすいようになっているものであれば、学習しても問題ないとしてほしい), (著作権者, 海賊版等の権利侵害複製物をAI学習のため複製することについて学習しても問題ないとしてほしい))',
#  'Pattern5 (筆者, (海賊版サイトで容易に読むことができる, スキャンしたものが違法に公開されている), (著作権者, 海賊版等の権利侵害複製物をAI学習のため複製することについて学習しても問題ないとしてほしい))',
#  'Pattern5 (筆者, (プロンプトによる画像生成で、プロンプトの内容で依拠性が否定できる場合, その作品を知っていたかどうかを推認するまでもなく依拠性が否定される), (規制当局, 特定のプロンプト入力については、生成をしないといった措置を推奨しないでほしい))',
#  'Pattern4 (筆者, 生成AIへの風当たりが強い状況, 魔女狩りじみている)',
#  'Pattern4 (筆者, 特定個人の作風を強く感じさせる出力物, 不特定多数への公開や企業での使用は著作権の違反になる可能性があるという状況)',
#  'Pattern4 (筆者, 特定個人の作風を強く感じさせる出力物の個人での楽しみ, 問題ないと捉えている)',
#  'Pattern4 (筆者, 特定個人の作風を強く感じさせる出力物の公開や企業での使用, 著作権の違反になる可能性があると捉えている)',
#  'Pattern4 (筆者, 特定個人の作風を強く感じさせる出力物に対する規制の提案, 非常に良い落としどころだと感じている)',
#  'Pattern2 (筆者, 開発者と創作者, 良い落としどころが見つかることを祈って欲しい)',
#  'Pattern4 (筆者, AIの使用に対する一般の拒否反応, 全ての人がAIを拒否しているわけではないと捉えている)',
#  'Pattern5 (筆者, (生成AIへの風当たりが強い状況, 魔女狩りじみている), (開発者と創作者, 良い落としどころが見つかることを祈って欲しい))',
#  'Pattern1 (筆者, 生成AIにおける選択行為, 創作的寄与の判断に影響しうると考える)',
#  'Pattern4 (筆者, 生成AIにおける選択行為, 創作的意図がないとは感じられない)',
#  'Pattern3 (生成AIにおける選択行為, 生成物の選択, 創作的意図上の合格基準ラインをすべてクリアしている状況を引き起こしている)',
#  'Pattern3 (生成AIにおける選択行為, 生成物の選択, 単純な印象としてのクオリティにいたるまでを勘案している状況を引き起こしている)',
#  'Pattern4 (筆者, 生成AIにおける選択行為, 確固たる創作的意図がなければ成し得ないものであると考える)',
#  'Pattern5 (筆者, (生成AIにおける選択行為, 創作的意図上の合格基準ラインをすべてクリアしている状況を引き起こしている), (生成AIにおける選択行為, 創作的寄与の判断に影響しうると考える))',
#  'Pattern5 (筆者, (生成AIにおける選択行為, 単純な印象としてのクオリティにいたるまでを勘案している状況を引き起こしている), (生成AIにおける選択行為, 創作的寄与の判断に影響しうると考える))',
#  'Pattern3 (拡大解釈, 学習・開発段階, 権利範囲を広げられてしまう懸念がある)',
#  'Pattern3 (AIの開発を委縮させてしまう効果が出ること, 学習・開発段階, 権利範囲を広げられてしまう懸念がある)',
#  'Pattern4 (筆者, 著作物を学習すること, 本来は有用な行為である)',
#  'Pattern2 (筆者, 研究機関や企業, 学習や開発を安心して実施できる状況を作ってほしい)',
#  'Pattern4 (筆者, プロンプトに著作物を含むケース, 是認されると認識している)',
#  'Pattern5 (筆者, (拡大解釈, 学習・開発段階, 権利範囲を広げられてしまう懸念がある), (研究機関や企業, 学習や開発を安心して実施できる状況を作ってほしい))',
#  'Pattern5 (筆者, (AIの開発を委縮させてしまう効果が出ること, 学習・開発段階, 権利範囲を広げられてしまう懸念がある), (研究機関や企業, 学習や開発を安心して実施できる状況を作ってほしい))',
#  'Pattern5 (筆者, (著作物を学習すること, 本来は有用な行為である), (研究機関や企業, 学習や開発を安心して実施できる状況を作ってほしい))',
#  'Pattern5 (筆者, (プロンプトに著作物を含むケース, 是認されると認識している), (研究機関や企業, 学習や開発を安心して実施できる状況を作ってほしい))',
#  'Pattern1 (筆者, 生成AIの学習に用いること, 権利者の許諾なしに禁止する法規制を望む)',
#  'Pattern3 (生成AI, 著作物, データとして取り込んでいる)',
#  'Pattern4 (筆者, 生成AIによる著作物の利用, 著作者の許諾が必要であると捉えている)',
#  'Pattern4 (筆者, 生成AIによる著作物の利用, 自分の著作物を勝手に使われることに非常に憤りを感じている)',
#  'Pattern3 (生成AI生成物, 著作物の著作者, 攻撃、嫌がらせに用いられている)',
#  'Pattern3 (生成AI, 創作者の創作意欲, 削がれてしまう状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AI, 若手創作者, 悪影響を与えている))',
#  'Pattern4 (筆者, 生成AIのフリーライド・攻撃・嫌がらせ, 日本の文化の破壊に繋がると捉えている)',
#  'Pattern5 (筆者, (生成AI, 著作物, データとして取り込んでいる), (生成AIの学習に用いること, 権利者の許諾なしに禁止する法規制を望む))',
#  'Pattern5 (筆者, (生成AI生成物, 著作物の著作者, 攻撃、嫌がらせに用いられている), (生成AIの学習に用いること, 権利者の許諾なしに禁止する法規制を望む))',
#  'Pattern5 (筆者, (生成AI, 創作者の創作意欲, 削がれてしまう状況を引き起こしている), (生成AIの学習に用いること, 権利者の許諾なしに禁止する法規制を望む))',
#  'Pattern1 (筆者, 生成AIの規制, 個人・非営利・研究利用においての制限は撤廃し、営利利用や一般の開放されたコミュニティへの投稿などには規制を掛けるべきである)',
#  'Pattern3 (生成AIの出力物, 既存の権利物, 酷似している)',
#  'Pattern4 (筆者, (イラストレーターの意見, 生成AI技術, 完全に停滞する状況を引き起こしている))',
#  'Pattern5 (筆者, (生成AIの出力物, 既存の権利物, 酷似している), (生成AIの規制, 個人・非営利・研究利用においての制限は撤廃し、営利利用や一般の開放されたコミュニティへの投稿などには規制を掛けるべきである))',
#  'Pattern5 (筆者, (イラストレーターの意見, 生成AI技術, 完全に停滞する状況を引き起こしている), (生成AIの規制, 個人・非営利・研究利用においての制限は撤廃し、営利利用や一般の開放されたコミュニティへの投稿などには規制を掛けるべきである))',
#  'Pattern2 (筆者, 政府, AIを規制し類似品が出ないかつ無関係のAIを巻き込まない対処をしてほしい)',
#  'Pattern2 (筆者, 政府, 正しく利用している者や被害者の意見を聞いてほしい)',
#  'Pattern3 (弁護士等, 事実に反することを平然と言う状況, 被害者が泣き寝入りし技術が停滞する状況を引き起こしている)',
#  'Pattern2 (筆者, 政府, 弁護士等の事実に反する意見を参考にする際は慎重に選択してほしい)',
#  'Pattern1 (生成AI推進派, クリエイターとの共存, 無視されるべきではない)',
#  'Pattern1 (筆者, AI製品に目印の挿入や学習元の管理, 必須である)',
#  'Pattern3 (現状の無法地帯な状況, まじめなクリエイター, 損をする状況を引き起こしている)',
#  'Pattern2 (筆者, 政府, まじめなクリエイターが損をしないように対策をしてほしい)',
#  'Pattern4 (筆者, NEUTRINO等歌唱ソフト関係の分野, 参考にすべきであると捉えている)',
#  'Pattern2 (筆者, 政府, 生成AIによって日本のクリエイターが潰されない法規制をしてほしい)',
#  'Pattern5 (筆者, (事実に反することを平然と言う状況, 被害者が泣き寝入りし技術が停滞する状況を引き起こしている), (政府, 弁護士等の事実に反する意見を参考にする際は慎重に選択してほしい))',
#  'Pattern5 (筆者, (現状の無法地帯な状況, まじめなクリエイター, 損をする状況を引き起こしている), (政府, まじめなクリエイターが損をしないように対策をしてほしい))',
#  'Pattern5 (筆者, (生成AI推進派, クリエイターとの共存, 無視されるべきではない), (政府, 生成AIによって日本のクリエイターが潰されない法規制をしてほしい))',
#  'Pattern5 (筆者, (NEUTRINO等歌唱ソフト関係の分野, 参考にすべきであると捉えている), (政府, 生成AIによって日本のクリエイターが潰されない法規制をしてほしい))',
#  'Pattern1 (筆者, 生成AIの規制, 必要である)',
#  'Pattern4 (著作者, SNSの発展, 生成AIの規制に関する印象に左右される状況)',
#  'Pattern3 (SNSの発展, 著作者の印象, 低迷させている)',
#  'Pattern3 (生成AI, 民間の扱い, 生成AIが民間に扱われるようになってから、心理上関連づけてしまい、不快感を抱いてしまう問題を膨大してしまっている)',
#  'Pattern4 (筆者, (生成AI, 民間の扱い, 生成AIが民間に扱われるようになってから、心理上関連づけてしまい、不快感を抱いてしまう問題を膨大してしまっている))',
#  'Pattern3 (生成AI, 人々, 腐す武器にも成ってしまっている)',
#  'Pattern3 (デマの情報, 人々, より信憑性を感じさせるようなデマの情報を発信できるようになってしまっている)',
#  'Pattern3 (著作者の作風に寄せた投稿, 著作者の評判, 評判を落とす行為がより数多く発信されるようになってしまっている)',
#  'Pattern4 (筆者, 生成AIが人々を腐す武器にも成ってしまっている問題, 日本とは何なのか、文化とは何なのかを問われている気がする)',
#  'Pattern3 (尊重すべき日本的な文化, 人々の気持ちが紡いだ文化, 潰れてしまう)',
#  'Pattern1 (人間, 日本, 尊重すべき日本的な文化が潰れてしまう状況であるが故にどう在るべきかを問われている)',
#  'Pattern5 (筆者, (生成AIが民間に扱われるようになってから、心理上関連づけてしまい、不快感を抱いてしまう問題を膨大してしまっている問題, 生成AIの規制), (生成AIの規制, 必要である))',
#  'Pattern5 (筆者, (生成AIが人々を腐す武器にも成ってしまっている状況で, 日本とは何なのか、文化とは何なのかを問われている気がする), (日本, 尊重すべき日本的な文化が潰れてしまう状況であるが故にどう在るべきかを問われている))',
#  'Pattern3 (AIイラスト, クリエイター, 仕事を奪われる事例が増えている)',
#  'Pattern1 (筆者, AIの学習行為, 著作権が適応されるべきである)',
#  'Pattern2 (筆者, 国民, 真剣に取り組むことを求める)',
#  'Pattern1 (筆者, 企業のAI生成イラスト又は小説の使用, 反対である)',
#  'Pattern5 (筆者, (AIイラスト, クリエイター, 仕事を奪われる事例が増えている), (AIの学習行為, 著作権が適応されるべきである))',
#  'Pattern5 (筆者, (AIイラスト, クリエイター, 仕事を奪われる事例が増えている), (国民, 真剣に取り組むことを求める))',
#  'Pattern5 (筆者, (AIイラスト, クリエイター, 仕事を奪われる事例が増えている), (企業のAI生成イラスト又は小説の使用, 反対である))',
#  'Pattern1 (筆者, 現生成AI, 規制すべきである)',
#  'Pattern3 (現生成AI, 個人の創作物, プロンプト次第で出せる状況を引き起こしている)',
#  'Pattern3 (現生成AI, 漫画村, ほぼ同じようなものである状況を引き起こしている)',
#  'Pattern4 (筆者, 現生成AI, 盗人であり無断転載をしている業者と大差がない)',
#  'Pattern3 (個人, 無断転載に対する訴訟, 時間も金もかかり非常にコストが高く全く現実的ではない状況を引き起こしている)',
#  'Pattern1 (筆者, 国家レベルでのAI規制, 企業に圧力をかけるべきである)',
#  'Pattern3 (創作物を学習させるとAIの挙動をおかしくさせる技術（Glaze）, 創作物, まともに学習できなくなる可能性がある状況を引き起こしている)',
#  'Pattern3 (創作物を学習させるとAIの挙動をおかしくさせる技術が浸透したとき, 手描きで作られた本物の創作物, 価値が高まりAI企業間での奪い合いになる状況を引き起こしている)',
#  'Pattern4 (筆者, (創作物を学習させるとAIの挙動をおかしくさせる技術が浸透したとき, 国, 世界から信頼されず乗り遅れAI後進国になる可能性が高い状況を引き起こしている))',
#  'Pattern3 (現状のままだと, 日本, AI競争に負ける可能性が非常に高い状況を引き起こしているか)',
#  'Pattern4 (筆者, 現在のAI技術, 信頼して使うことができないと捉えているか)',
#  'Pattern3 (各企業でのAI使用, 消費者, 疑心暗鬼となり信頼を失う現象を引き起こしているか)',
#  'Pattern4 (プロの漫画家, 自分の作品に他人の著作物が入り込むこと, 信頼を損なうことを恐れていると捉えているか)',
#  'Pattern3 (第三者がAIを通して, 若手イラストレーターや画家, 商売にならない状況を引き起こしているか)',
#  'Pattern3 (イラストを描く人口の減少, 絵柄の進歩, 衰退する恐れがある状況を引き起こしているか)',
#  'Pattern1 (筆者, AI企業との個人契約における法整備, 本人だけが著作権をクリアした自分特化の学習データを使えるようにすべきである)',
#  'Pattern1 (筆者, 日本独自のAI規制, 若手クリエイターを守るべきである)',
#  'Pattern2 (筆者, OPENAI企業, 若い需要のあるクリエイターの画風を極度に学習させ、ほぼ同じ絵を出すことに圧力をかけて欲しい)',
#  'Pattern3 (日本人の著作物を世界中誰でも使え、販売できる現状, 若いクリエイター, お金がいきわたらない状況を引き起こしている)',
#  'Pattern3 (お金がいきわたらない状況, 若いクリエイター, 絵を描く時間を失い新しい絵柄や表現が出来なくなる状況を引き起こしている)',
#  'Pattern3 (本物のデータが減った日本, 日本, AI競争に負け、文化面でも衰退していく状況を引き起こしている)',
#  'Pattern4 (筆者, (日本人の著作物を世界中誰でも使え、販売できる現状, 日本, 国益を大きく害している))',
#  'Pattern5 (筆者, (現生成AI, 個人の創作物, プロンプト次第で出せる状況を引き起こしている), (現生成AI, 規制すべきである))',
#  'Pattern5 (筆者, (現生成AI, 漫画村, ほぼ同じようなものである状況を引き起こしている), (現生成AI, 規制すべきである))',
#  'Pattern5 (筆者, (創作物を学習させるとAIの挙動をおかしくさせる技術（Glaze）, 創作物, まともに学習できなくなる可能性がある状況を引き起こしている), (国家レベルでのAI規制, 企業に圧力をかけるべきである))',
#  'Pattern5 (筆者, (創作物を学習させるとAIの挙動をおかしくさせる技術が浸透したとき, 手描きで作られた本物の創作物, 価値が高まりAI企業間での奪い合いになる状況を引き起こしている), (国家レベルでのAI規制, 企業に圧力をかけるべきである))',
#  'Pattern5 (筆者, (創作物を学習させるとAIの挙動をおかしくさせる技術が浸透したとき, 国, 世界から信頼されず乗り遅れAI後進国になる可能性が高い状況を引き起こしている), (国家レベルでのAI規制, 企業に圧力をかけるべきである))',
#  'Pattern5 (筆者, (現状のままだと, 日本, AI競争に負ける可能性が非常に高い状況を引き起こしている), (国家レベルでのAI規制, 企業に圧力をかけるべきである))',
#  'Pattern5 (筆者, (日本人の著作物を世界中誰でも使え、販売できる現状, 日本, 国益を大きく害している), (日本独自のAI規制, 若手クリエイターを守るべきである))',
#  'Pattern5 (筆者, (お金がいきわたらない状況, 若いクリエイター, 絵を描く時間を失い新しい絵柄や表現が出来なくなる状況を引き起こしている), (日本独自のAI規制, 若手クリエイターを守るべきである))',
#  'Pattern5 (筆者, (本物のデータが減った日本, 日本, AI競争に負け、文化面でも衰退していく状況を引き起こしている), (日本独自のAI規制, 若手クリエイターを守るべきである))',
#  'Pattern3 (AI, 著作権所持者の作品, 価値を著しく下げている)',
#  'Pattern3 (AI生成物の販売, 著作権所持者の生活, 脅かしている)',
#  'Pattern4 (筆者, AIによる製作物の利用, 技術と製作物の窃盗であり立派な著作権の侵害である)',
#  'Pattern1 (筆者, 著作権物に対してAI技術の使用, 禁止されるべきである)',
#  'Pattern1 (筆者, 著作権所持者とその作品の保護, 最優先されるべきである)',
#  'Pattern1 (筆者, 著作権物に対してAI技術の使用を禁止し、著作権所持者とその作品の保護を最優先にするための法案作成と違反者（著作権物へのAI使用者）への罰則を作り、その後取り締まりを強化するべきである, 実施されるべきである)',
#  'Pattern5 (筆者, (AI生成物の販売, 著作権所持者の生活, 脅かしている), (著作権物に対してAI技術の使用, 禁止されるべきである))',
#  'Pattern5 (筆者, (AI, 著作権所持者の作品, 価値を著しく下げている), (著作権物に対してAI技術の使用, 禁止されるべきである))',
#  'Pattern5 (筆者, (AIによる製作物の利用, 技術と製作物の窃盗であり立派な著作権の侵害である), (著作権物に対してAI技術の使用, 禁止されるべきである))',
#  'Pattern3 (現在の生成AIの在り方, 著作権者の市場, 衝突している)',
#  'Pattern3 (生成AIの使用, 著作権者の利益, 不当に害している)',
#  'Pattern3 (海賊版サイトでのトレーニング, 著作物の代替, 間接的に行わせている)',
#  'Pattern3 (生成AI, 著作権者の利益, 不当に害する可能性を拡大または促進している)',
#  'Pattern3 (フリーライダー, 著作権者の市場, 大量の類似生成物を作り破壊している)',
#  'Pattern3 (無償で公開された生成物, 潜在的な利益または対価回収の機会, 奪っている)',
#  'Pattern4 (筆者, (現在の生成AIの在り方, 著作権者の市場, 衝突している), 文化の発展を阻害していると捉えている)',
#  'Pattern4 (筆者, (生成AIの使用, 著作権者の利益, 不当に害している), 文化の発展を阻害していると捉えている)',
#  'Pattern1 (筆者, ベルヌ条約に抵触する可能性の根拠, 客観的証拠を用いて証明するべきである)',
#  'Pattern1 (筆者, 権利制限規定の在り方, より一層慎重になるべきである)',
#  'Pattern1 (筆者, 著作権者の権利が正当に保護される規制案, 確立が迫られている)',
#  'Pattern1 (筆者, AIシステム, 国際的に足並みを揃えて規制する必要がある)',
#  'Pattern1 (筆者, 著作物ではないものを搾取的な手段で大量生産するシステム, これまで以上に著作権者の権利を保護する対応に迫られている)',
#  'Pattern3 (許諾を得ていないデータ, 権利者の対価回収の機会, 奪うこと)',
#  'Pattern3 (許諾を得ていないデータ, ベルヌ条約, 抵触する可能性がある)',
#  'Pattern3 (日本の主張する非享受利用の範囲, ベルヌ条約, 抵触する恐れが否定できない)',
#  'Pattern4 (筆者, (許諾を得たデータでのみトレーニングをする, 海外のトレーニングデータの権利者, ライセンス料を支払うか許諾を得るという考え方に舵を切り始めている))',
#  'Pattern1 (筆者, 著作権法改正, 海外を中心に発生することが想定される)',
#  'Pattern3 (AI汎用モデルに対するトレーニングデータの監視・共有、著作権法の順守、オプトアウト権利の保護など, EUのAI法, 示されている)',
#  'Pattern1 (筆者, 搾取的なAIシステムに対する規制, 厳格であるべきである)',
#  'Pattern1 (筆者, 著作権者あるいは著作者の権利の保護, 速やかであるべきである)',
#  'Pattern5 (筆者, (現在の生成AIの在り方, 著作権者の市場, 衝突している), (権利制限規定の在り方, より一層慎重になるべきである))',
#  'Pattern5 (筆者, (生成AIの使用, 著作権者の利益, 不当に害している), (著作権者の権利が正当に保護される規制案, 確立が迫られている))',
#  'Pattern5 (筆者, (無償で公開された生成物, 潜在的な利益または対価回収の機会, 奪っている), (著作権者の権利を保護する対応, これまで以上に迫られている))',
#  'Pattern5 (筆者, (許諾を得ていないデータ, 権利者の対価回収の機会, 奪うこと), (ベルヌ条約, 抵触する可能性がある))',
#  'Pattern5 (筆者, (日本の主張する非享受利用の範囲, ベルヌ条約, 抵触する恐れが否定できない), (権利制限規定の在り方, より一層慎重になるべきである))',
#  'Pattern1 (筆者, 生成AI使用者の振る舞い, 考慮しないまたは蔑ろにするべきではない)',
#  'Pattern1 (筆者, AI学習使用禁止の文言, 法的拘束力があるべきである)',
#  'Pattern2 (筆者, 法整備, クリエイターが控える様な意見に対して誹謗中傷や政治的思想を伴った反論をしないようにすること)',
#  'Pattern3 (生成AI使用者, クリエイターの意見, 誹謗中傷や政治的思想を伴った反論を引き起こしている)',
#  'Pattern3 (生成AI, 長年の研鑽によって生み出された画風や表現, 陳腐化させている)',
#  'Pattern3 (実在人物のポルノ, 投稿サイト, 汚染して学習元の人物の尊厳を傷つけている)',
#  'Pattern3 (生成AI, クリエイター, 不当な投稿制限を受けさせている)',
#  'Pattern2 (筆者, 政府, 生成AI提供者は常に学習データを開示、或いは請求に対して開示する義務を持つこと)',
#  'Pattern2 (筆者, 政府, 生成AI提供者及び利用者は学習データ提供に同意したクリエイターの作品のみ利用可能で、それに反した場合法的な罰則を設けること)',
#  'Pattern2 (筆者, 政府, 生成AIによって生成された作品に著作権や利用料の設定を認めず、誰でも二次利用可能とすること)',
#  'Pattern2 (筆者, 政府, 学習データ提供の拒否を無視した生成AI利用者の行動に対して嫌がらせやストーキング、誹謗中傷に並ぶ法的措置を取れる様にすること)',
#  'Pattern5 (筆者, (生成AI使用者, クリエイターの意見, 誹謗中傷や政治的思想を伴った反論を引き起こしている), (政府, 生成AI提供者は常に学習データを開示、或いは請求に対して開示する義務を持つこと))',
#  'Pattern5 (筆者, (生成AI, 長年の研鑽によって生み出された画風や表現, 陳腐化させている), (政府, 生成AIによって生成された作品に著作権や利用料の設定を認めず、誰でも二次利用可能とすること))',
#  'Pattern5 (筆者, (実在人物のポルノ, 投稿サイト, 汚染して学習元の人物の尊厳を傷つけている), (政府, 生成AI提供者及び利用者は学習データ提供に同意したクリエイターの作品のみ利用可能で、それに反した場合法的な罰則を設けること))',
#  'Pattern3 (従来の著作権法との整合性, 現在権利者が盗作ではないかと訴えている件, 対応できない状況を引き起こしている)',
#  'Pattern3 (法曹・警察, 現在権利者が盗作ではないかと訴えている件, 取り合っていない状況を引き起こしている)',
#  'Pattern4 (筆者, (AI絵が多数の画像を元にしている事, 特定作家の狙い撃ちモデルに混じる他の多数の絵, 法ではセーフという結論になっている))',
#  'Pattern3 (ネットに画像を流した瞬間, AIの元にされる事, 非常にアンバランスかつ人権の侵害とも取れる状況を引き起こしている)',
#  'Pattern3 (似た画風で成人向けを描いていない作家が成人向け絵を生成される事案, 名誉の毀損, 引き起こしている)',
#  'Pattern1 (筆者, 拒否権を作家に与えた上で許可を取った物のみで研究, 進めるべきである)',
#  'Pattern4 (筆者, クリエイターの人権を無視した非常に危険な状態, あまりにクリエイター軽視である)',
#  'Pattern3 (研究目的、また享受を伴わない場合のみ著作権者の許可を必要としないという文言, 実態に伴っていない, 引き起こしている)',
#  'Pattern4 (筆者, 生成物でCM、販売などをしているもの, 享受には当たらないというのは無理があると捉えている)',
#  'Pattern4 (筆者, 罰則の無い状態, 形骸化されていると捉えている)',
#  'Pattern4 (筆者, 画像生成AIの出力物が国内ではなく海外のアーティストの画風が強く出ている状況, 世界全ての著作者の把握ができており、それらを全く侵害していない状態であると判断できているか疑問であると捉えている)',
#  'Pattern3 (児童ポルノや犯罪現場、医療データの画像, データセット, 使用しても良いという認識を引き起こしている)',
#  'Pattern3 (児童ポルノや犯罪現場、医療データの画像が含まれたデータセットの販売経路, 世界中の信用, 信用の失墜を引き起こしている)',
#  'Pattern3 (児童ポルノや犯罪現場、医療データの画像が含まれたデータセットの販売経路, 本国の作品, 拒絶を引き起こしている)',
#  'Pattern4 (筆者, (児童ポルノや犯罪現場、医療データの画像が含まれたデータセットの販売経路, 世界中の信用, 信用の失墜を引き起こしている))',
#  'Pattern4 (筆者, (児童ポルノや犯罪現場、医療データの画像が含まれたデータセットの販売経路, 本国の作品, 拒絶を引き起こしている))',
#  'Pattern1 (筆者, 生成物の著作性, 一切与えられるべきではない)',
#  'Pattern1 (筆者, 生成AIの規制, 必要である)',
#  'Pattern3 (生成AI, 作家達, 無秩序に作品を利用されている状況を引き起こしている)',
#  'Pattern3 (生成AI, 作家達, 心を痛めさせ、筆を置かせている)',
#  'Pattern3 (声をあげている人, 作家の権利, 脅迫被害を受けている状況を引き起こしている)',
#  'Pattern4 (筆者, 画像生成AIの使用意図, 作家の精神性を無視し、安く都合のいい絵が欲しいだけであると捉えている)',
#  'Pattern3 (画像生成AI, 文化の発展, 全く見出せない状況を引き起こしている)',
#  'Pattern3 (業界の状況, 文化, 先細りし、潰える原因になっている)',
#  'Pattern3 (生成AI, 写真の被写体, 簡単に裸にされる事や名誉を著しく傷つける事ができる状況を引き起こしている)',
#  'Pattern1 (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである)',
#  'Pattern2 (筆者, 社会, プライバシー、著作権、パブリシティ権などあらゆる権利の軽視が多く見られる状況にもう少しだけ危機感を持った発信をして欲しい)',
#  'Pattern3 (昨今の情勢, ネットに作品を上げること, まるで悪いのだと言わんばかりの状況を引き起こしている)',
#  'Pattern2 (筆者, クリエイター, もう少し寄り添った舵取りをして欲しい)',
#  'Pattern5 (筆者, (生成AI, 作家達, 無秩序に作品を利用されている状況を引き起こしている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, 作家達, 心を痛めさせ、筆を置かせている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern5 (筆者, (声をあげている人, 作家の権利, 脅迫被害を受けている状況を引き起こしている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern5 (筆者, (画像生成AI, 文化の発展, 全く見出せない状況を引き起こしている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern5 (筆者, (業界の状況, 文化, 先細りし、潰える原因になっている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, 写真の被写体, 簡単に裸にされる事や名誉を著しく傷つける事ができる状況を引き起こしている), (筆者, 画像生成AIの使用, 一部研究機関、研究者のみに制限し、最低限の倫理問題をクリアできてから免許所有者のみ利用可能、まで制限をかけるべきである))',
#  'Pattern4 (筆者, 生成AIによるイラスト生成の楽しみ, この世の終わりである)',
#  'Pattern4 (筆者, 生成AIの学習に関しての問題, 現時点では問題ない)',
#  'Pattern1 (筆者, 日本の生成AIの土壌, よい土壌であるべきである)',
#  'Pattern5 (筆者, (生成AIによるイラスト生成の楽しみがこの世の終わりである, 生成AIの楽しみ), (日本の生成AIの土壌, よい土壌であるべきである))',
#  'Pattern5 (筆者, (生成AIの学習に関しての問題が現時点では問題ない, 生成AIの学習問題), (日本の生成AIの土壌, よい土壌であるべきである))',
#  'Pattern1 (筆者, 生成AIのデータセット, 100％クリーンであるべきである)',
#  'Pattern3 (児童ポルノ被害者の実画像が入っているデータセット, 生成AI, 世界的に規制の流れを引き起こしている)',
#  'Pattern3 (使用者, クリエイターの作品, 悪影響を及ぼしている)',
#  'Pattern3 (データセットの問題, 生成AI, 規制の流れになっている)',
#  'Pattern1 (筆者, ただの複製製造装置である生成AIの推進, やめるべきである)',
#  'Pattern4 (筆者, このテクノロジーを持て囃すこと, 愚行であり世界に遅れを取ることになる)',
#  'Pattern5 (筆者, (児童ポルノ被害者の実画像が入っているデータセット,生成AI,世界的に規制の流れを引き起こしている), (生成AIのデータセット,100％クリーンであるべきである))',
#  'Pattern5 (筆者, (データセットの問題,生成AI,規制の流れになっている), (生成AIのデータセット,100％クリーンであるべきである))',
#  'Pattern5 (筆者, (使用者,クリエイターの作品,悪影響を及ぼしている), (生成AIの推進,やめるべきである))',
#  'Pattern5 (筆者, (生成AIの推進を持て囃すこと,愚行であり世界に遅れを取ることになる), (生成AIの推進,やめるべきである))',
#  'Pattern1 (筆者, 現生成AI, 規制すべきである)',
#  'Pattern4 (筆者, (現生成AI, 創作物, 誰でも出せてしまう状況を引き起こしているか))',
#  'Pattern3 (現生成AI, 創作物, 誰でも出せてしまう状況を引き起こしている)',
#  'Pattern3 (現生成AI, 創作物, 無断転載と変わらない状況を引き起こしている)',
#  'Pattern3 (漫画村の取り締まり, 漫画村, 行政によって潰された状況を引き起こしているか)',
#  'Pattern4 (筆者, AI, それとほぼ同じようなものである)',
#  'Pattern4 (筆者, 漫画やアニメがプロンプト次第で出てくる状態, そのまま出てくるのではないでしょうか)',
#  'Pattern4 (筆者, AI開発企業, 盗人であり、無断転載をしている業者と大差がない)',
#  'Pattern3 (個人が裁判をすること, 無断転載, 時間も金もかかり、非常にコストが高く、全く現実的ではない状況を引き起こしているか)',
#  'Pattern4 (筆者, 若者の所得が数百万程度である状況, これでどうやって戦えというのでしょうか)',
#  'Pattern1 (筆者, 国家レベルでのAI規制, 企業に圧力をかけるべきである)',
#  'Pattern3 (アンチ学習システム（Glaze）の登場, 創作物を学習させると, AIの挙動をおかしくさせるものが登場している状況を引き起こしているか)',
#  'Pattern3 (生成AI技術, 創作物, まともに学習できなくなる可能性がある)',
#  'Pattern3 (生成AI技術の浸透, 手描きの創作物, 価値が高まる)',
#  'Pattern3 (手描きの創作物の価値の高まり, AI企業間, 奪い合いになる)',
#  'Pattern4 (筆者, (規制をしっかりとしていなかった国, 世界からの信頼, 信頼されず乗り遅れる), AI後進国になる可能性が高いと考えている)',
#  'Pattern4 (筆者, (現状のまま進行すると, 日本, AI競争に負ける), 非常に高い可能性があると考えている)',
#  'Pattern4 (筆者, (AI使用が炎上している各企業, 消費者, 疑心暗鬼となる), AIであることがバレると信頼を失う現象が起きている)',
#  'Pattern4 (筆者, (プロの漫画家である自分, 自分の作品, 他人の著作物が入り込む), 信頼を損なうことを恐れ使えない)',
#  'Pattern3 (第三者, 若手イラストレーターや画家の著作物, 商売にならない状況を引き起こしている)',
#  'Pattern3 (AI, イラストを描く人口, 減少させている)',
#  'Pattern3 (AI, 絵柄の進歩, 衰退させる恐れがある)',
#  'Pattern1 (筆者, 法整備, 個人がAI企業と契約し自分特化の学習データを使えるようにすべきである)',
#  'Pattern1 (筆者, 日本のAI規制, 若手クリエイターを守るべきである)',
#  'Pattern2 (筆者, OPENAI企業, 日本の若い需要のあるクリエイターの画風を極度に学習させずに圧力をかけるようにして欲しい)',
#  'Pattern3 (現状, 国益, 大きく害している)',
#  'Pattern3 (若いクリエイター, 絵を描く時間, 失っている)',
#  'Pattern3 (若いクリエイター, 新しい絵柄や表現, 出きなくなっている)',
#  'Pattern3 (日本, AI競争, 負けている)',
#  'Pattern4 (筆者, (日本, 文化面, 衰退していく), この世の終わりである)',
#  'Pattern5 (筆者, (現生成AI, 創作物, 誰でも出せてしまう状況を引き起こしている), (現生成AI, 規制すべきである))',
#  'Pattern5 (筆者, (現生成AI, 創作物, 無断転載と変わらない状況を引き起こしている), (現生成AI, 規制すべきである))',
#  'Pattern5 (筆者, (アンチ学習システム（Glaze）の登場, 創作物を学習させると, AIの挙動をおかしくさせるものが登場している状況を引き起こしている), (国家レベルでのAI規制, 企業に圧力をかけるべきである))',
#  'Pattern5 (筆者, (生成AI技術の浸透, 手描きの創作物, 価値が高まる), (手描きの創作物の価値の高まり, AI企業間, 奪い合いになる))',
#  'Pattern5 (筆者, (規制をしっかりとしていなかった国, 世界からの信頼, 信頼されず乗り遅れる), (日本, AI後進国になる可能性が高いと考えている))',
#  'Pattern5 (筆者, (現状のまま進行すると, 日本, AI競争に負ける), (日本のAI規制, 若手クリエイターを守るべきである))',
#  'Pattern5 (筆者, (AI使用が炎上している各企業, 消費者, 疑心暗鬼となる), (OPENAI企業, 日本の若い需要のあるクリエイターの画風を極度に学習させずに圧力をかけるようにして欲しい))',
#  'Pattern3 (元が許可なく集められたイラストの数々, イラストレーターの時間と努力, 価値を培われているもので描かれている状況を引き起こしている)',
#  'Pattern4 (筆者, (元が許可なく集められたイラストの数々, イラストレーターの作品の価値, 人権の侵害に相当するレベルである))',
#  'Pattern4 (筆者, (イラストレーターの作品の価値を蔑ろにする行為による悪感情, AIの使用, クリエーターが信用を失う物になっている状況を引き起こしている))',
#  'Pattern1 (筆者, 人の尊厳を無視したままのAI, 一度使用を制限する必要がある)',
#  'Pattern5 (筆者, (イラストレーターの時間と努力によって培われたもので描かれたイラスト, 人権の侵害に相当するレベルである), (AI, 一度使用を制限する必要がある))',
#  'Pattern5 (筆者, (イラストレーターの作品の価値を蔑ろにする行為による悪感情, クリエーターが信用を失う物になっている状況を引き起こしている), (AI, 一度使用を制限する必要がある))',
#  'Pattern2 (筆者, AI生成画像, 必ず生成時に自動でAIである表記が入るようにしてほしい)',
#  'Pattern2 (筆者, AI画像の使用者, どんなに小さな場所でも些細な箇所でもそれがAIによるものが含まれている場合AIであるという表記を義務付けてほしい)',
#  'Pattern2 (筆者, AIの学習に使う者, 必ず元の画像の権利者の許可が必要と義務付けしてほしい)',
#  'Pattern2 (筆者, AI学習に使われた元画像の権利者, １枚ごとに相応のお金を支払うべき)',
#  'Pattern2 (筆者, AIの学習プロセス, 一般ユーザーが自由にデータを追加できないよう義務付けしてほしい)',
#  'Pattern2 (筆者, AI画像に対して, 権利画像が使われていないか求められた場合その証拠を提示しなければならないようにしてほしい)',
#  'Pattern3 (生成AI, 他文化の担い手, 攻撃的意図で使われる状況を引き起こしている)',
#  'Pattern4 (筆者, 著作権法が生成AIを他文化の担い手に対して攻撃的意図で使う用途で利用されること, 本末転倒である)',
#  'Pattern1 (筆者, 他文化の尊重, 文化の発展に欠かせない倫理的規範であるべきである)',
#  'Pattern4 (ファッションローガイドブック2023, 文化の盗用, 非倫理的行為である)',
#  'Pattern5 (筆者, (生成AI, 他文化の担い手, 攻撃的意図で使われる状況を引き起こしている), (他文化の尊重, 文化の発展に欠かせない倫理的規範であるべきである))',
#  'Pattern5 (筆者, (著作権法が生成AIを他文化の担い手に対して攻撃的意図で使う用途で利用されること, 本末転倒である), (他文化の尊重, 文化の発展に欠かせない倫理的規範であるべきである))',
#  'Pattern5 (筆者, (文化の盗用, 非倫理的行為である), (他文化の尊重, 文化の発展に欠かせない倫理的規範であるべきである))',
#  'Pattern3 (生成AIの根幹にあるデータセット, 日本を代表するコンテンツ産業, つぶす事になる)',
#  'Pattern1 (国, 生成AIの根幹にあるデータセットが盗作、盗用、無断学習、さらに児童ポルノなどの非人道的なデータで成り立っている事実を国民に知らせること, 当たり前である)',
#  'Pattern1 (筆者, 著作権で生成AIによる無断学習などから守る法規制, 必要である)',
#  'Pattern5 (筆者, (生成AIの根幹にあるデータセット, 日本を代表するコンテンツ産業, つぶす事になる), (国, 生成AIの根幹にあるデータセットが盗作、盗用、無断学習、さらに児童ポルノなどの非人道的なデータで成り立っている事実を国民に知らせること, 当たり前である))',
#  'Pattern5 (筆者, (生成AIの根幹にあるデータセット, 日本を代表するコンテンツ産業, つぶす事になる), (筆者, 著作権で生成AIによる無断学習などから守る法規制, 必要である))',
#  'Pattern3 (現状世に出回っているAI生成のもの, データセット, 著作権違反をしている状態である)',
#  'Pattern3 (利用者, 作品の著者, 誹謗中傷を行う道具になっている)',
#  'Pattern1 (筆者, 許諾を得られていないソフト, 法律的に違法であるべきである)',
#  'Pattern1 (筆者, 著者またはドメインを持つ財団, 著作権料を支払うべきである)',
#  'Pattern4 (筆者, 発想の助け, 素晴らしいと捉えている)',
#  'Pattern1 (筆者, 生成AIについての対応, もっと大々的にプロ・アマチュア問わず意見を聞いていくべきである)',
#  'Pattern5 (筆者, (現状世に出回っているAI生成のもの, データセット, 著作権違反をしている状態である), (著者またはドメインを持つ財団, 著作権料を支払うべきである))',
#  'Pattern5 (筆者, (利用者, 作品の著者, 誹謗中傷を行う道具になっている), (著者またはドメインを持つ財団, 著作権料を支払うべきである))',
#  'Pattern1 (筆者, 生成AI, 大きく規制をかけるべきである)',
#  'Pattern3 (生成AI, クリエイターのアイデンティティー, 盗まれ、勝手にバラ撒かれたも同然のような状況を引き起こしている)',
#  'Pattern3 (生成AI, まだ世に出ていないこれから活躍する若いクリエイター, 脅威にしかならない状況を引き起こしている)',
#  'Pattern3 (生成AI, 長い時間をかけて磨いてきたもの, 簡単に安上がりのコンテンツとなって流れていく状況を引き起こしている)',
#  'Pattern3 (生成AI, 新しいもの, 新しいものを作りあげてもまた生成AIに盗まれて、の繰り返しでマンガ.アニメ業界を著しく衰退させうる存在となることもそう想像に固くありません)',
#  'Pattern4 (筆者, (生成AI, クリエイターの大切な作品, 学習させてクリエイターは用済みのゴミ扱いとなる状況を引き起こしている))',
#  'Pattern4 (筆者, 生成AIの現状, この世の終わりである)',
#  'Pattern4 (筆者, 著作権法, 今活躍しているクリエイターとこれからの業界を支えていく人を守る為にあるものである)',
#  'Pattern2 (筆者, 政府, クリエイターを守る道を選んで欲しい)',
#  'Pattern5 (筆者, (生成AI, クリエイターのアイデンティティー, 盗まれ、勝手にバラ撒かれたも同然のような状況を引き起こしている), (生成AI, 大きく規制をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, まだ世に出ていないこれから活躍する若いクリエイター, 脅威にしかならない状況を引き起こしている), (生成AI, 大きく規制をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, 長い時間をかけて磨いてきたもの, 簡単に安上がりのコンテンツとなって流れていく状況を引き起こしている), (生成AI, 大きく規制をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, 新しいもの, 新しいものを作りあげてもまた生成AIに盗まれて、の繰り返しでマンガ.アニメ業界を著しく衰退させうる存在となることもそう想像に固くありません), (生成AI, 大きく規制をかけるべきである))',
#  'Pattern5 (筆者, (生成AI, クリエイターの大切な作品, 学習させてクリエイターは用済みのゴミ扱いとなる状況を引き起こしている), (生成AI, 大きく規制をかけるべきである))',
#  'Pattern5 (筆者, (生成AIの現状, この世の終わりである), (政府, クリエイターを守る道を選んで欲しい))',
#  'Pattern1 (筆者, 企業または個人が無断でAIに著作物を学習させる行為, 制限されるべきである)',
#  'Pattern1 (筆者, 学習を拒む権利, 必要である)',
#  'Pattern3 (一人の著作者のデータを集中学習させること, 著作者の画風, 酷似させている)',
#  'Pattern3 (集中学習データセットの無断販売, 個人による追加学習, 無法地帯である状況を引き起こしている)',
#  'Pattern4 (筆者, 一人の著作者のデータを集中学習させることによって画風を酷似させる問題, 筆を折る事態や精神的苦痛を訴える者まで現れている状況である)',
#  'Pattern1 (筆者, 新しい法による抑止力, 必要である)',
#  'Pattern3 (AI開発事業者・AIサービス提供者, プロンプトの制限, 著作権侵害の防止が出来ない事例を多数報告している)',
#  'Pattern4 (筆者, 生成AIサービスにおける著作権侵害問題に対する企業の責任を負わない姿勢, 問題である)',
#  'Pattern1 (筆者, 生成AIサービスにおける著作権侵害問題に対する企業の責任, 生成命令を出した者と企業の両者に負わせるべきである)',
#  'Pattern1 (筆者, 生成AIが著作権侵害のリスクを持つことに対する法規制の検討, 視野に検討すべきである)',
#  'Pattern3 (生成AI, クリエーターの仕事, 奪われている状況を引き起こしているか)',
#  'Pattern3 (生成AI, クリエーター, 勝ち目がない状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AI使用の明記とクリエーターの保護, 義務化するなどが必要であると考えられる)',
#  'Pattern4 (筆者, (生成AI, クリエーターの仕事, 奪われている状況を引き起こしているか), 今後無規制のまま乱用されていけば起きてしまうことが予想できる)',
#  'Pattern4 (筆者, 生成AIを使用しているかどうか消費者が分からない現状と悪意のある販売者が身元を偽って利益を得ることができる状況, 不当である)',
#  'Pattern4 (筆者, 生成AIによる違法画像のロンダリング, 世界的に問題視されている)',
#  'Pattern3 (生成AI, 違法画像, ロンダリングを可能にしている)',
#  'Pattern4 (専門家や文化庁, 海外の生成AIに対する動向, 知らないまたは見て見ぬふりをしている)',
#  'Pattern4 (筆者, 生成AIに対する議論, 懐疑的な目を向けざるを得ない状況)',
#  'Pattern1 (筆者, 生成AIの規制, より厳しくあるべきである)',
#  'Pattern4 (筆者, アメリカや韓国、イギリスの生成AI規制の事例や報道、研究記事, 注目すべきである)',
#  'Pattern5 (筆者, (一人の著作者のデータを集中学習させることによって画風を酷似させる問題, 筆を折る事態や精神的苦痛を訴える者まで現れている状況である), (企業または個人が無断でAIに著作物を学習させる行為, 制限されるべきである))',
#  'Pattern5 (筆者, (集中学習データセットを無断で販売する者まで現れ、個人による追加学習は無法地帯である状況, 著作権侵害として裁くことが出来るかもしれないが、費用対効果の面や、次から次へと被害が発生点から、個人の力では追加学習の拒否や被害の発生の抑止をすることが出来ない), (新しい法による抑止力, 必要である))',
#  'Pattern5 (筆者, (生成される物が著作権侵害の防止することは出来ない事例が多数報告されている, AI開発事業者・AIサービス提供者による技術的な措置), (生成AIサービスにおける著作権侵害問題に対する企業の責任, 生成命令を出した者と企業の両者に負わせるべきである))',
#  'Pattern1 (筆者, 生成AIの成果物, 純粋に成果物に対して既存の著作権を侵害するものかについて意見する)',
#  'Pattern1 (筆者, 著作権法, 変更を加える必要はない)',
#  'Pattern3 (生成AIの技術的な背景について, AI成果物, 既存の著作物を模倣することが問題であると思う)',
#  'Pattern1 (筆者, 学習した既存の著作物と一定の割合以上一致しないなどの措置, 必要だと思う)',
#  'Pattern1 (筆者, 著作権, AIの開発において足かせにならないように規制などをするべきである)',
#  'Pattern4 (筆者, 既存の著作物に酷似した独創性の低い成果物, 問題であると思う)',
#  'Pattern4 (筆者, 生成物の著作物性, 既存の著作物を学習していても、組み合わせや用途など、成果物に独創性があれば、著作物と言えると捉えている)',
#  'Pattern4 (筆者, 生成AIサービスが著作権を侵害するかについての論点, 学習する素材や、成果物が既存の著作物に酷似していることが問題であると捉えている)',
# ...
#  'Pattern3 (無法状態の生成AI, イラスト, 勝手に使われている)',
#  'Pattern4 (筆者, 無法状態の生成AI, 不安である)',
#  'Pattern5 (筆者, (無法状態の生成AI, クリエイターなど様々な人の権利, 脅かす恐れがある), (法整備, 法整備を求める))',
#  'Pattern5 (筆者, (無法状態の生成AI, イラスト, 勝手に使われている), (法整備, 法整備を求める))',
#  'Pattern5 (筆者, (無法状態の生成AI, 不安である), (法整備, 法整備を求める))',
#  'Pattern1 (筆者, 生成AIによる被害の自衛手段としてglaze等の加工, 可能にすべきである)',
#  'Pattern3 (生成AI, クリエイターの権利, 無断学習を回避するのは不可能である状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIに使われているデータセット, 不当に学習されたデータがほとんどである状態から変える必要がある)',
#  'Pattern1 (筆者, 生成AI, 無断で学習させる行為を防ぐことが困難なため自衛手段としてglaze等の加工を可能にすべきである)',
#  'Pattern1 (筆者, AIによって作られた生成物, 透かし等を入れることを義務化すべきである)',
#  'Pattern3 (生成AI, 若い世代のクリエイター, クリエイターの意欲を削ぐ結果を引き起こしている)',
#  'Pattern1 (筆者, 若い世代のクリエイター, 守るべきである)',
#  'Pattern1 (筆者, 生成AIの透明性, 重要である)',
#  'Pattern3 (生成AI, 画像, 不当に学習されている)',
#  'Pattern3 (生成AIが使用している画像の中には, 児童ポルノ画像やセンシティブな画像, 犯罪となり得る状況を含んでいる)',
#  'Pattern4 (筆者, (生成AIが使用している画像の中には, 児童ポルノ画像やセンシティブな画像, 犯罪となり得る状況を含んでいる), 処罰がないことに疑問符が浮かぶ)',
#  'Pattern1 (筆者, 透明な生成AIの使用, 義務付けるべきである)',
#  'Pattern5 (筆者, (生成AI, クリエイターの権利, 無断学習を回避するのは不可能である状況を引き起こしている), (生成AIによる被害の自衛手段としてglaze等の加工, 可能にすべきである))',
#  'Pattern5 (筆者, (生成AI, 若い世代のクリエイター, クリエイターの意欲を削ぐ結果を引き起こしている), (若い世代のクリエイター, 守るべきである))',
#  'Pattern5 (筆者, (生成AIが使用している画像の中には, 児童ポルノ画像やセンシティブな画像, 犯罪となり得る状況を含んでいる), (透明な生成AIの使用, 義務付けるべきである))',
#  'Pattern1 (筆者, 生成AIの評価, 経済、貿易の観点だけでなく、文化が発展するための環境及びイノベーションを支援する環境の評価もするべきである)',
#  'Pattern4 (筆者, 生成AIに対する意見の相違, これらの環境を作り出していると感じるかどうかの違いが大きい)',
#  'Pattern1 (文化審議会文化政策部会 文化多様性に関する作業部会, 文化的財、サービスの流通, 異なる文化的表現の共存を保障し、文化多様性との相互補完的な関係を構築できるように、経済、貿易の観点からのみでなく、文化そのものの観点から検討していくことが必要である)',
#  'Pattern1 (統合イノベーション戦略推進会議, AI-Readyな社会, リアル空間も含めたあらゆるデータが新鮮かつ安全にAI解析可能なレベルで利用可能であり、かつ、プライバシーやセキュリティが確保されることで、誰もが安心してデータを提供し流通させることができ、提供したデータから便益を得られる環境ができていることが求められる)',
#  'Pattern3 (生成AI, 著作者やデータが豊富な文化, 一方的に生成AI利用者の私的利益を手助けする仕組みになっている)',
#  'Pattern4 (筆者, (生成AI, 著作者やデータが豊富な文化, 一方的に生成AI利用者の私的利益を手助けする仕組みになっている))',
#  'Pattern4 (筆者, 生成AIが生む環境, 他文化との共存や多文化主義との相互補完的な関係、誰もが安心してデータを提供し流通させることができ提供したデータから便益を得られる環境等を目指しているものとは思えない)',
#  'Pattern5 (筆者, (生成AI, 他文化との共存や多文化主義との相互補完的な関係、誰もが安心してデータを提供し流通させることができ提供したデータから便益を得られる環境等を目指しているものとは思えない), (生成AI, 一方的に生成AI利用者の私的利益を手助けする仕組みになっている))',
#  'Pattern5 (筆者, (生成AI, 一方的に生成AI利用者の私的利益を手助けする仕組みになっている), (文化的財、サービスの流通, 異なる文化的表現の共存を保障し、文化多様性との相互補完的な関係を構築できるように、経済、貿易の観点からのみでなく、文化そのものの観点から検討していくことが必要である))',
#  'Pattern1 (筆者, AIによる作品の模倣, 規制されるべきである)',
#  'Pattern3 (AI, 作家さんたちの作品, 簡単に模倣している)',
#  'Pattern3 (特定の個人の作品を学習させたAIイラスト, 作家さん, 侮辱している)',
#  'Pattern3 (AIによる作品の模倣, 作家さんたち, 心を病む要因となっている)',
#  'Pattern3 (AI, 日本のアニメ・イラスト文化, 脅かしている)',
#  'Pattern2 (筆者, 政府, AI規制を検討して欲しい)',
#  'Pattern5 (筆者, (AIによる作品の模倣, 作家さんたち, 心を病む要因となっている), (政府, AI規制を検討して欲しい))',
#  'Pattern5 (筆者, (特定の個人の作品を学習させたAIイラスト, 作家さん, 侮辱している), (政府, AI規制を検討して欲しい))',
#  'Pattern1 (筆者, AI 学習のための著作物の複製等を防止するための、機械可読な方法による技術的な措置, 特段の制限は設けられておらず自由に行うことが可能である)',
#  'Pattern1 (筆者, 著作権侵害の被害者, 対策コストを負わされるべきではない)',
#  'Pattern1 (筆者, 著作権者が反対の意思を示していること, 権利制限規定の対象から除外されると解釈することは困難)',
#  'Pattern1 (筆者, AI学習を許可している著作権者からの学習, 法改正によってのみ可とする)',
#  'Pattern3 (画像生成AI, データセット, 児童ポルノ等で汚染されている状況を引き起こしている)',
#  'Pattern1 (筆者, 画像生成AIの公的使用, 問題がある)',
#  'Pattern3 (Stable Diffusion等, 作家個人の絵柄データセット, 本人の同意なしに作成される状況を引き起こしている)',
#  'Pattern1 (筆者, Stable Diffusion等を用い作家個人の絵柄データセットを本人の同意なしに作成するなど倫理的に悪辣な行為, 悪辣な行為である)',
#  'Pattern3 (AI生成データ, 手書きの作品文化圏, 荒らされている状況を引き起こしている)',
#  'Pattern3 (アマチュア文化圏, 生成AIの画像, 混乱を引き起こしている状況を引き起こしている)',
#  'Pattern4 (筆者, (画像生成AI, 美術的かつ技術的マイルストーンと呼べるべき現象や作品、業界のポジティブな変化, 認められていない状況を引き起こしている))',
#  'Pattern3 (生成AI, インターネット上の学術的証明手段, 疑う必要が出てきている)',
#  'Pattern3 (ニセ情報の拡散, インターネット, 急速に進んでいる)',
#  'Pattern4 (筆者, 整列された図書館に紛らわしいゴミが投入されている状況, 異様に紛らわしいゴミが投入されているようなものである)',
#  'Pattern4 (筆者, 我が国が擁する非常に巨大なアマチュア文化圏, 最大の文化的な宝であり、国際競争力のある独自コンテンツヒットの要因であると考えている)',
#  'Pattern1 (筆者, 我が国が擁する非常に巨大なアマチュア文化圏や彼らの創作意欲を損なわない社会システム, コンテンツ立国を目指す我が国が真っ先に取り組むべきである)',
#  'Pattern4 (筆者, AIの規制, 足かせにしかなっていない)',
#  'Pattern5 (筆者, (画像生成AI, データセット, 児童ポルノ等で汚染されている状況を引き起こしている), (画像生成AIの公的使用, 問題がある))',
#  'Pattern5 (筆者, (Stable Diffusion等, 作家個人の絵柄データセット, 本人の同意なしに作成される状況を引き起こしている), (Stable Diffusion等を用い作家個人の絵柄データセットを本人の同意なしに作成するなど倫理的に悪辣な行為, 悪辣な行為である))',
#  'Pattern5 (筆者, (AI生成データ, 手書きの作品文化圏, 荒らされている状況を引き起こしている), (我が国が擁する非常に巨大なアマチュア文化圏や彼らの創作意欲を損なわない社会システム, コンテンツ立国を目指す我が国が真っ先に取り組むべきである))',
#  'Pattern5 (筆者, (アマチュア文化圏, 生成AIの画像, 混乱を引き起こしている状況を引き起こしている), (我が国が擁する非常に巨大なアマチュア文化圏や彼らの創作意欲を損なわない社会システム, コンテンツ立国を目指す我が国が真っ先に取り組むべきである))',
#  'Pattern3 (生成AI, イラストの生成, 学習データに頼り切っている)',
#  'Pattern3 (生成AI, データセット, 無断で学習している)',
#  'Pattern1 (筆者, AIによる無断学習, 取り締まるべきである)',
#  'Pattern4 (筆者, 生成AIが芸術及び社会の発展に重要な技術, このことに異論はない)',
#  'Pattern4 (筆者, 無断で他人のデータを使用すること, 許されざる行為である)',
#  'Pattern5 (筆者, (生成AI, イラストの生成, 学習データに頼り切っている), (AIによる無断学習, 取り締まるべきである))',
#  'Pattern5 (筆者, (生成AI, データセット, 無断で学習している), (AIによる無断学習, 取り締まるべきである))',
#  'Pattern5 (筆者, (生成AIが芸術及び社会の発展に重要な技術, このことに異論はない), (無断で他人のデータを使用すること, 許されざる行為である))',
#  'Pattern3 (追加学習が簡単にできる環境, 作風が類似するもの, 簡単に作れるようになっている)',
#  'Pattern3 (インターネット上での許可していない追加学習, 追加学習のデータの配布, 嫌がらせを引き起こしている)',
#  'Pattern2 (筆者, 学習を拒否する方法がない状況, 最低限オプトアウトさせて欲しい)',
#  'Pattern1 (筆者, 学習の方法, オプトイン方式であるべきである)',
#  'Pattern3 (生成AI, クリエイター, 育たなくなりコンテンツ創作の好循環が阻害される)',
#  'Pattern3 (生成AI, インターネットの検索欄, 不正確な情報で汚染し人間の学習を阻害する)',
#  'Pattern3 (生成AI製の情報, 生成AIの学習, どんどん生成物が大量のゴミ情報になっていく可能性がある)',
#  'Pattern3 (生成AIの学習, 個人のクリエイター, 監視できる範囲が狭いので著作権侵害がなかなか発覚しない)',
#  'Pattern1 (筆者, 生成AIの学習, 無差別に行われないようにあるべきである)',
#  'Pattern1 (筆者, 学習範囲, オプトインにした方が良い)',
#  'Pattern5 (筆者, (生成AI, クリエイター, 育たなくなりコンテンツ創作の好循環が阻害される), (学習の方法, オプトイン方式であるべきである))',
#  'Pattern5 (筆者, (生成AI, インターネットの検索欄, 不正確な情報で汚染し人間の学習を阻害する), (学習範囲, オプトインにした方が良い))',
#  'Pattern4 (筆者, AI利用者の懸念, 将来起こりうるリスクとして記載されている)',
#  'Pattern4 (筆者, AI利用者の懸念, 2024年1月現在では既に実害を伴って顕在化してしまった問題として捉えている)',
#  'Pattern3 (クリエイター自身が生成AIを利用した場合, SNSでの騒動, クリエイターが生成AIを利用することができない風潮を形成してしまっている)',
#  'Pattern4 (筆者, 漫画の背景には既に生成AIが広く使われているという憶測, 周囲の反応はそれらは素材集を購入して使ったものだ、私の漫画には生成AIは使っていませんといった反応が寄せられている)',
#  'Pattern3 (周囲の反応, 漫画の背景には既に生成AIが広く使われているという憶測, それらは素材集を購入して使ったものだ、私の漫画には生成AIは使っていませんといった反応が寄せられている)',
#  'Pattern4 (筆者, 著作権や評判を重視するクリエイターが生成AIを利用することができず、それらを軽視する者がこぞって生成AIを利用するという状況, 不公平感を感じている)',
#  'Pattern3 (著作権と生成AIの考え方が成熟しきっていないこと, 生成AI利用における不安, 引き起こしている)',
#  'Pattern2 (筆者, 貴庁, 考え方の整理を行い生成AI利用における不安を解消して欲しい)',
#  'Pattern1 (筆者, 素案, 次の提案を行うべきである)',
#  'Pattern1 (筆者, ＜AI 利用者の懸念＞の節, クリエイター自身がAI利用者として生成AIを利用する場合の文言を補足として付け加えるべきである)',
#  'Pattern3 (クリエイターの生成AI活用が萎縮してしまっている状態, ＜AI 利用者の懸念＞の節, 明記されている)',
#  'Pattern5 (筆者, (著作権と生成AIの考え方が成熟しきっていないこと, 生成AI利用における不安, 引き起こしている), (貴庁, 考え方の整理を行い生成AI利用における不安を解消して欲しい))',
#  'Pattern5 (筆者, (クリエイター自身が生成AIを利用した場合, SNSでの騒動, クリエイターが生成AIを利用することができない風潮を形成してしまっている), (＜AI 利用者の懸念＞の節, クリエイター自身がAI利用者として生成AIを利用する場合の文言を補足として付け加えるべきである))',
#  'Pattern1 (筆者, 生成AIが誰にでも触れられる現在の環境, 歯止めをかけるべきである)',
#  'Pattern3 (生成AI, 偽札作り・ディープフェイク・特殊詐欺, 人々が騙される状況を引き起こしている)',
#  'Pattern3 (倫理観が育ち切っていない子供や破滅願望を持った人間, 国家関係, 悪化させるきっかけを作っている)',
#  'Pattern1 (筆者, 生成AIに触れることができるのは免許を持った者や医療・介護といった人手不足により存続が危ぶまれている分野に絞る, 一般人が安易に手出しができないようにするべきである)',
#  'Pattern3 (生成AI, 一般人の手, 特殊詐欺で人を騙す為に多量の電気が消費される状況を引き起こしている)',
#  'Pattern3 (生成AI, 一般人の手, 貧しい人々が電気代の高騰について行けず暖をとれない状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIを一般人の手に許してしまうことによる特殊詐欺や電気代の高騰による貧しい人々の苦境, 避けるべきである)',
#  'Pattern3 (生成AI, クリエイター達の作品, 無許可無断で集めてきたデータセットで動いている状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AI, クリエイター達の作品, 無許可無断で集めてきたデータセットで動いている状況を引き起こしている), 問題があると捉えている)',
#  'Pattern3 (自分の家族の顔写真や声でディープフェイク, ネット, 拡散される状況を引き起こしている)',
#  'Pattern3 (自分の家族の顔写真や声でディープフェイクが作られたもの, ネット, 根本的に消去不可能な状況を引き起こしている)',
#  'Pattern3 (クリエイター達の作品, 生成AI, 無断無許可で取り込まれ性的な作品を出力される状況を引き起こしている)',
#  'Pattern4 (筆者, 加害者側の行為, 合法だからと言い切っている)',
#  'Pattern3 (声を上げた方の画像, 生成AI, 無断で機械学習されて絵柄を複製する状況を引き起こしている)',
#  'Pattern4 (筆者, (声を上げた方の画像, 生成AI, 無断で機械学習されて絵柄を複製する状況を引き起こしている))',
#  'Pattern3 (文化庁が許可した言葉, 被害者, 泣き寝入りするしかない状況を引き起こしている)',
#  'Pattern3 (無法, 被害者, 泣き寝入りするしかない状況を引き起こしている)',
#  'Pattern3 (無法, 作家, 自殺に追い込まれている状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIの規制, 一刻も早く必要である)',
#  'Pattern5 (筆者, (生成AI, 一般人の手, 特殊詐欺で人を騙す為に多量の電気が消費される状況を引き起こしている), (生成AIを一般人の手に許してしまうことによる特殊詐欺や電気代の高騰による貧しい人々の苦境, 避けるべきである))',
#  'Pattern5 (筆者, (生成AI, クリエイター達の作品, 無許可無断で集めてきたデータセットで動いている状況を引き起こしている), (生成AIの規制, 一刻も早く必要である))',
#  'Pattern5 (筆者, (声を上げた方の画像, 生成AI, 無断で機械学習されて絵柄を複製する状況を引き起こしている), (被害者, 泣き寝入りするしかない状況を引き起こしている))',
#  'Pattern1 (筆者, 従来の著作権法の考え方との整合性について現行法ではいくつかの要件を満たさなければ著作権違反が認められないがこれはおかしい, おかしい)',
#  'Pattern1 (筆者, 従来の著作権法の考え方, 絵柄にも著作権を認めるべきである)',
#  'Pattern3 (AI利用者, イラストレーターの個性である絵柄, イラストレーターが受けるべき利益をかすめ取る状況を引き起こしている)',
#  'Pattern4 (筆者, イラストレーターが受けるべき利益をAI利用者が模倣した絵柄でかすめ取る状況, 最も問題視されている点である)',
#  'Pattern1 (筆者, 生成AIについて生成した絵図, 既存の著作物の切り貼りではないとされるがその根拠が乏しい)',
#  'Pattern1 (筆者, 生成AI, どの著作物を利用したかその元データを追跡、確認できる仕組みを導入しなければならない)',
#  'Pattern1 (筆者, 生成AIによる画像, 視覚的、電子的な、解除不可能な証明を埋め込む必要がある)',
#  'Pattern1 (筆者, 営利目的の学習および生成画像の使用, 利用された著作物の権利者に妥当な額の報酬を支払うべきである)',
#  'Pattern3 (音楽教室での既存の著作物の利用, 著作権料の発生, 判例によってやる気を無くさせている)',
#  'Pattern1 (筆者, AIの学習に利用された絵図, 著作権者に著作権料を支払うべきである)',
#  'Pattern4 (筆者, 生成物の著作物性, 生成物の著作物性について認めるべきではない)',
#  'Pattern4 (筆者, AIによる生成で人間の意思、思想が介在しない, 生成物の著作物性について認めるべきではない)',
#  'Pattern4 (筆者, プロンプトの入力, 単なる指示である)',
#  'Pattern4 (筆者, AI利用者の好み, その良し悪しを判断するだけである)',
#  'Pattern3 (AIによる画像生成, 人間による創造の結果付随する著作性, 根本から異なる状況を引き起こしている)',
#  'Pattern3 (人間による創作, 時間, 非常に時間がかかる状況を引き起こしている)',
#  'Pattern3 (公開された未完成品, AI, 完成させる状況を引き起こしている)',
#  'Pattern3 (公開された未完成品, 著作権の主張, 悪質なケースを引き起こしている)',
#  'Pattern1 (筆者, AIによる生成物に対する著作権, 認めるべきではない)',
#  'Pattern5 (筆者, (イラストレーターが受けるべき利益をAI利用者が模倣した絵柄でかすめ取る状況, 最も問題視されている点である), (従来の著作権法の考え方, 絵柄にも著作権を認めるべきである))',
#  'Pattern5 (筆者, (生成AIについて生成した絵図は既存の著作物の切り貼りではないとされるがその根拠が乏しい, 生成AIがどの著作物を利用したかその元データを追跡、確認できる仕組みを導入しなければならない), (生成AI, どの著作物を利用したかその元データを追跡、確認できる仕組みを導入しなければならない))',
#  'Pattern5 (筆者, (公開された未完成品を取り込み、AIによって完成させ、先に著作権を主張する悪質なケース, AIによる生成物に対する著作権, 認めるべきではない), (AIによる生成物に対する著作権, 認めるべきではない))',
#  'Pattern4 (筆者, (法第 30 条の4本文に規定する条項, 法第 30 条の4本文に規定する条項, 極端に拡大解釈されている状況を引き起こしているか))',
#  'Pattern1 (筆者, 法第 30 条の4本文に規定する条項, 原則として適用すべきでない)',
#  'Pattern1 (筆者, 法第 30 条の4本文に規定する条項, 混乱を招いているだけである)',
#  'Pattern1 (筆者, 法第 30 条の4本文に規定する条項, 裁判をすることを前提にした規定に変更するべきである)',
#  'Pattern3 (少数派の株主, 会社の合併などの重要な議案, 反対することができる)',
#  'Pattern1 (法律, 買い取り価格の交渉が決裂した場合, 裁判を行うことが明記されているべきである)',
#  'Pattern1 (会社法第469条と第470条, 交渉が決裂した場合の裁判手続き, 明確に条件が記載されている)',
#  'Pattern1 (筆者, 著作権法第30条の4の但し書き, 「お互いが同意した場合もしくは裁判を行ったとき限定」にするべきである)',
#  'Pattern4 (筆者, 著作権法第30条の4の但し書き, 無駄な争いがなくなると捉えている)',
#  'Pattern5 (筆者, (著作権法第30条の4の但し書き, 極端に拡大解釈されている状況を引き起こしているか), (著作権法第30条の4の但し書き, 原則として適用すべきでない))',
#  'Pattern5 (筆者, (著作権法第30条の4の但し書き, 極端に拡大解釈されている状況を引き起こしているか), (著作権法第30条の4の但し書き, 混乱を招いているだけである))',
#  'Pattern5 (筆者, (著作権法第30条の4の但し書き, 極端に拡大解釈されている状況を引き起こしているか), (著作権法第30条の4の但し書き, 裁判をすることを前提にした規定に変更するべきである))',
#  'Pattern5 (筆者, (著作権法第30条の4の但し書き, 無駄な争いがなくなると捉えている), (著作権法第30条の4の但し書き, 「お互いが同意した場合もしくは裁判を行ったとき限定」にするべきである))',
#  'Pattern3 (生成AIを用いた絵, イラストレーター・声優・小説家・俳優業, 被害を被っている状況を引き起こしている)',
#  'Pattern1 (筆者, 生成AIの規制, 可能な限り著作者側からの対処が可能なようにするべきである)',
#  'Pattern1 (筆者, 生成AIの利用, AI生成ツールが開発した企業とそのAI生成ツールを明示することが必要である)',
#  'Pattern4 (筆者, 生成AIを用いた絵について、既存のイラストレーターなどの著作物を無断で学習用の素材とし、それを利用して商用利用をするなどの行為があまりにも多い状態, 一刻も早い生成AIへの対処が必要であると捉えている)',
#  'Pattern5 (筆者, (生成AIを用いた絵, イラストレーター・声優・小説家・俳優業, 被害を被っている状況を引き起こしている), (生成AIの規制, 可能な限り著作者側からの対処が可能なようにするべきである))',
#  'Pattern5 (筆者, (生成AIを用いた絵について、既存のイラストレーターなどの著作物を無断で学習用の素材とし、それを利用して商用利用をするなどの行為があまりにも多い状態, 一刻も早い生成AIへの対処が必要であると捉えている), (生成AIの利用, AI生成ツールが開発した企業とそのAI生成ツールを明示することが必要である))',
#  'Pattern3 (AIイラストの学習量, 人間の学習量, 桁違いである)',
#  'Pattern3 (AIイラストの学習量の大半, 学習データ, 無許可である)',
#  'Pattern4 (筆者, (AIイラストの学習量の大半が無許可の学習であること, 国立図書館がデータベース化した蔵書のデータを無断で使うことよりも多い分量である))',
#  'Pattern1 (筆者, 図書館の利用, 許可が必要である)',
#  'Pattern1 (筆者, 個人情報の登録, 必要である)',
#  'Pattern1 (筆者, 蔵書の持ち出し, 制限がかかるべきである)',
#  'Pattern3 (個人の作業結果の学習, 個人の作業結果, ハードルが高い)',
#  'Pattern4 (筆者, (AI生成, いいところだけを無断で取り混ぜて出力したものである), 模写と同じと言えば聞こえはいいが実際は異なる)',
#  'Pattern1 (筆者, AIイラスト等の生成サイトとの特別な契約関係, ないこと)',
#  'Pattern1 (筆者, 生成を指示した人物に著作権等が発生すること, ないこと)',
#  'Pattern1 (筆者, 生成物を利用しての販売, 根拠がないこと)',
#  'Pattern1 (筆者, この部分の関係性, 法律で明示すべきである)',
#  'Pattern1 (筆者, 生成AIの規制に関する意見の場合, 生成の指示者、生成サイトの運営会社、生成を行ったAI、学習元となった成果物の著作権者の著作権法における明確化を行うべきである)',
#  'Pattern3 (生成の指示者, 学習元となった成果物の著作権者, 何の権利も有していない状況を引き起こしている)',
#  'Pattern3 (生成サイトの運営会社, 学習成果という利益, 全ての利益を吸収する状況を引き起こしている)',
#  'Pattern4 (筆者, (生成の指示者, 学習元となった成果物の著作権者, 何の権利も有していない状況を引き起こしている), 生成AIの規制に関する意見の場合)',
#  'Pattern1 (筆者, 1～4の権利関係, 明確であるべきである)',
#  'Pattern1 (筆者, 4の保護, 最優先であるべきである)',
#  'Pattern5 (筆者, (AIイラストの学習量の大半が無許可の学習であること, 国立図書館がデータベース化した蔵書のデータを無断で使うことよりも多い分量である), (図書館の利用, 許可が必要である))',
#  'Pattern5 (筆者, (生成の指示者, 学習元となった成果物の著作権者, 何の権利も有していない状況を引き起こしている), (生成AIの規制に関する意見の場合, 生成の指示者、生成サイトの運営会社、生成を行ったAI、学習元となった成果物の著作権者の著作権法における明確化を行うべきである))',
#  'Pattern5 (筆者, (生成サイトの運営会社, 学習成果という利益, 全ての利益を吸収する状況を引き起こしている), (生成AIの規制に関する意見の場合, 生成の指示者、生成サイトの運営会社、生成を行ったAI、学習元となった成果物の著作権者の著作権法における明確化を行うべきである))',
#  'Pattern1 (筆者, 生成AIによる著作権侵害, 正当に対価を支払うべきである)',
#  'Pattern1 (筆者, 生成AIによる著作権侵害, 著作権侵害となる)',
#  'Pattern1 (筆者, 生成AIによる著作権侵害, 人道的にまずい)',
#  'Pattern1 (筆者, クリエイターが無断で素材にされてしまうこと, 考えることをやめるだろう)',
#  'Pattern1 (筆者, クリエイターが無断で素材にされてしまうこと, 文化の停滞を招く)',
#  'Pattern1 (筆者, クリエイターが無断で素材にされてしまうこと, 非常に危険な行いである自覚をもつべきである)',
#  'Pattern3 (生成AI, 児童ポルノ画像の学習, 実際に居る人間を殆ど再現出来てしまっている状態にある)',
#  'Pattern1 (政府, 生成AIの規制, 速やかに法整備し人々を守るべきである)',
#  'Pattern5 (筆者, (生成AI, 児童ポルノ画像の学習, 実際に居る人間を殆ど再現出来てしまっている状態にある), (政府, 速やかに法整備し人々を守るべきである))',
#  'Pattern5 (筆者, (生成AI, 児童ポルノ画像の学習, 実際に居る人間を殆ど再現出来てしまっている状態にある), (生成AI, 正当に対価を支払うべきである))',
#  'Pattern5 (筆者, (生成AI, 児童ポルノ画像の学習, 実際に居る人間を殆ど再現出来てしまっている状態にある), (生成AI, 著作権侵害となる))',
#  'Pattern5 (筆者, (生成AI, 児童ポルノ画像の学習, 実際に居る人間を殆ど再現出来てしまっている状態にある), (生成AI, 人道的にまずい))',
#  'Pattern1 (筆者, AIに対する規制, 不要である)',
#  'Pattern1 (筆者, AIに対する規制, 最低限であるべき)',
#  'Pattern1 (筆者, AI利用者による創作的寄与, 認めるべきではない)',
#  'Pattern3 (AI利用者, 指示と表現との因果関係, 創造性はほとんど関与していない状況を引き起こしている)',
#  'Pattern4 (筆者, AI利用者の立場, 依頼人に相当するものと捉えている)',
#  'Pattern4 (筆者, 米国著作権局の2023年3月16日のAI生成物に関する著作物登録ガイダンス, 人間が創作したものではないとされている)',
#  'Pattern5 (筆者, (指示と表現との因果関係, AI利用者の創造性はほとんど関与していない状況を引き起こしている), (AI利用者による創作的寄与, 認めるべきではない))',
#  'Pattern5 (筆者, (AI利用者の立場, 依頼人に相当するものと捉えている), (AI利用者による創作的寄与, 認めるべきではない))',
#  'Pattern1 (筆者, AIの画像学習による画像生成などによる著作権の侵害がインターネットで散見される現状, 技術的措置または法的な強い措置が必要である)',
#  'Pattern1 (筆者, 機械的アルゴリズムの基礎データ, 所持・使用を禁止されるべきである)',
#  'Pattern1 (筆者, AI学習において海賊版など権利侵害複製物から学習すること, 容認してはならない)',
#  'Pattern1 (筆者, AI生成物による著作権侵害, AI開発事業者および生成AI利用者が状況に応じて責任を負うべきである)',
#  'Pattern4 (筆者, 著作物の学習経路および著作権者への対価還元, 課題が多いと捉えている)',
#  'Pattern3 (AI生成, 既存作品, 影響を及ぼしている)',
#  'Pattern3 (画像生成AIの俗語の「マスピ顔」, 既存の作風, 価値を落としている)',
#  'Pattern3 (AI生成物, 作品の鑑賞, 疑念を持たれ阻害する状況を引き起こしている)',
#  'Pattern3 (AI生成物の氾濫, 検索結果, 汚染を引き起こしている)',
#  'Pattern3 (生成AIの普及, 信頼性の高い情報へのアクセス, いっそう困難になる状況を引き起こしている)',
#  'Pattern4 (筆者, (生成AIの学習, 本質的な理解ではなく模倣であること, 作品の質を落とす状況を引き起こしている))',
#  'Pattern4 (筆者, (AI生成物, 信頼性, 些か欠いている))',
#  'Pattern3 (AI生成物の信頼性, 文化, 衰退を招く)',
#  'Pattern3 (生成AIの生成の速度, 人力, 遥かに上回っている)',
#  'Pattern3 (生成AI, クリエイター等専門家, 技術や知識を複製・改変されていく)',
#  'Pattern3 (生成AI, 初学者, 意欲を削いでいる)',
#  'Pattern3 (生成AI, 研鑽のための資料, 汚染している)',
#  'Pattern1 (筆者, 生成AIの出力, 一定の制限を設けること)',
#  'Pattern1 (筆者, クリエイター等専門家への支援, 惜しまないこと)',
#  'Pattern1 (筆者, クリエイター等専門家の土壌, 汚さないこと)',
#  'Pattern2 (筆者, 生成AIの普及, 以下のような仕組みの実現を望む)',
#  'Pattern1 (筆者, AI生成物, ウォーターマークをつけるのを義務づけること)',
#  'Pattern1 (筆者, AI生成物, 容易に検索結果から除外できること)',
#  'Pattern1 (筆者, 生成AIの学習データの収集, 著作権者の許諾を不可欠とすること)',
#  'Pattern1 (筆者, 生成AIの学習データとしての作品利用, 著作権者へ対価を還元すること)',
#  'Pattern5 (筆者, (AI生成, 既存作品, 影響を及ぼしている), (AI生成物, 容易に検索結果から除外できること))',
#  'Pattern5 (筆者, (AI生成物, 作品の鑑賞, 疑念を持たれ阻害する状況を引き起こしている), (AI生成物, ウォーターマークをつけるのを義務づけること))',
#  'Pattern5 (筆者, (生成AIの普及, 信頼性の高い情報へのアクセス, いっそう困難になる状況を引き起こしている), (生成AIの学習データの収集, 著作権者の許諾を不可欠とすること))',
#  'Pattern5 (筆者, (生成AI, クリエイター等専門家, 技術や知識を複製・改変されていく), (クリエイター等専門家への支援, 惜しまないこと))',
#  'Pattern3 (画像生成サービス, クリエイターの作品, 無慈悲に学習している)',
#  'Pattern4 (筆者, (画像生成サービス, クリエイターの作品, 無慈悲に学習している))',
#  'Pattern1 (筆者, 現行の著作権法, 追い付いていないと捉えている)',
#  'Pattern4 (筆者, 画像生成サービス, 従来の著作権法の考え方との整合性について追い付いていないと捉えている)',
#  'Pattern4 (筆者, (画像生成AI, 趣味の範囲での使用, 人間としてモラルのある行いではないと捉えている))',
#  'Pattern4 (筆者, (自分の画像が使われること, 趣味の範囲での使用, 嫌であると捉えている))',
#  'Pattern3 (クリエイター, 創作物, 我が子のように思っている状況を引き起こしている)',
#  'Pattern3 (法律, 何をしてもいいという状況, OKである状況を引き起こしている)',
#  'Pattern4 (筆者, (自分の子どもの写真を勝手に改変され、それを売買されている, おぞましい状態であると捉えている))',
#  'Pattern4 (筆者, クールジャパンとされる作品, 誰が創作しているか)',
#  'Pattern4 (筆者, クールジャパンとされる作品の創作者の気持ち, 無視されている状況)',
#  'Pattern3 (創作者の気持ちを無視する状態, クールジャパンとされる作品, 見限られる状況を引き起こしている)',
#  'Pattern4 (筆者, AI推進の委員会の状況, 明らかに出来レースで動いていると捉えている)',
#  ...]

# %% [markdown]
# # Create docs

# %%
doc_info,docs = [],[]
cnt = 0
error_cnt = 0
record2hantei_2 = dict()
for i in range(len(out_edges)):
    if "Pattern5" in out_edges[i]:
        cnt += 1 
        try:
            tmp_list = parse_pattern(out_edges[i])
            source = tmp_list[1].strip("()")
            v1 = source.split(",")
            target = tmp_list[2].strip("()")
            v2 = target.split(",")   
            
            if (len(v1) >= 2) and (len(v1) <= 3) and (len(v2) >= 2) and (len(v2) <= 3):
                if len(v1) == 3:
                    #source = v1[0] + "が" + v1[1] + "に対して" + v1[2]
                    source_sub = v1[0]
                    source_obj = v1[1] + "に対して" + v1[2]
                    source_obj = source_obj.replace(" ","")
                    source =  source_sub  + "が" + source_obj
                    source = source.replace(" ","")
                else:
                    source_sub = v1[0]
                    source_obj = v1[1] 
                    source =  source_sub  + "が" + source_obj
                    source = source.replace(" ","")

                if len(v2) == 3:
                    target_sub = v2[0]
                    target_obj = v2[1] + "に対して" + v2[2]
                    target_obj = target_obj.replace(" ","")
                    target =  target_sub  + "が" + target_obj
                    target = target.replace(" ","")          
                else:
                    target_sub = v2[0]
                    target_obj = v2[1] 
                    target =  target_sub  + "が" + target_obj
                    target = target.replace(" ","")    
            
                record = str(out_info[i]) + "," + source + "。\n" + target + "。"
                if record not in record2hantei_2:
                    doc_info.append([out_info[i]])
                    docs.append(source + "。\n" + target + "。")   
                    record2hantei_2.update({record:1})
            
        except:
            error_cnt += 1
            #print(1)
            
print("Number of error: " + str(error_cnt))
# Out:
# Number of error: 3

# %%
print("Number of documents: " + str(len(docs)))
print("Number of documents: " + str(len(doc_info)))
print("Number of unique: " + str(len(list(set(docs)))))
# Out:
# Number of documents: 6003
# Number of documents: 6003
# Number of unique: 5998

# %%
tmp_hantei = dict()
for i in range(len(docs)):
    if docs[i] not in tmp_hantei:
        tmp_hantei.update({docs[i]:1})
    else:
        print(doc_info[i])
        print(docs[i])
# Out:
# [2312]
# 手描きとAI絵の判別がトラブルにならないか不安である。
# 生成AIが規制もしくは免許制にして欲しい。
# [2545]
# 生成AIが手描きとAI絵に対して判別がつかずトラブルになる状況を引き起こしている。
# 生成AIが規制もしくは免許制にして欲しい。
# [2618]
# 手描きとAI絵の判別がトラブルにならないか不安である。
# 生成AIが規制もしくは免許制にして欲しい。
# [2620]
# 生成AIが手描きとAI絵に対して判別がつかずトラブルになる状況を引き起こしている。
# 生成AIが規制もしくは免許制にして欲しい。
# [2873]
# 手描きとAI絵の判別がトラブルにならないか不安である。
# 生成AIが規制もしくは免許制にして欲しい。

# %% [markdown]
# # GPT

# %%
##############
openai.api_key = "YOUR-KEY"
##############
model = tiktoken.get_encoding("cl100k_base")

# %%
now = datetime.datetime.now()
LOG_FILE = os.path.join("log_public", "public_summarize_C_api_" +  use_model  + "_"+ now.strftime('%Y-%m-%dT%H_%M_%S') + ".log") 

if os.path.exists("log_public") == False:
    os.makedirs("log_public")

print(LOG_FILE)

def get_completion(messages, model=use_model):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        response_format={"type":"json_object"},
        temperature=0, 
    )
    return response.choices[0].message["content"]

DOLLAR_PER_TOKEN = 0.002/1000
YEN_PER_DOLLAR= 139.69

# トークン数とコストを計算
def check_tokens(prompt, model):
    tokens = model.encode(prompt)
    num_tokens = len(tokens)
    cost_dollar = len(tokens)*DOLLAR_PER_TOKEN
    cost_yen = len(tokens)*DOLLAR_PER_TOKEN*YEN_PER_DOLLAR
    return num_tokens, cost_dollar, cost_yen

def load_record(path,record2hantei):

    with open(path, "r") as f:
        lines = f.readlines()
    out_edges = []
    
    for kkk in range(len(lines)):
        #kkk = 0
        data = json.loads(lines[kkk])
        answer = data["answer"]
        text = data['input']
        date = data["date"]
        now_future = data["type"]
        record = date + ";" + now_future + ";" + text
        record2hantei.update({record:1})
# Out:
# log_public/public_summarize_C_api_gpt-4-turbo-2024-04-09_2024-10-24T22_45_44.log

# %% [markdown]
# # Prompt

# %%
prompt_template_1 = """
次のような文章が与えられます。与えられた文章は、「文1であるから文2をしてほしい」という規範的主張か、「文1であるから文2であるべきである」という要望を表しています。

この文章は、文2の内容に応じて二つの形式で要約されます：

文2が規範的主張をしている場合、要約は「AがBであるから、CはDであるべきである」となります。この要約の作成にあたって、文1からは「AがBである」という部分を抽出し、文2からは「CはDであるべきである」または「CはDすべきである」という表現を抽出します。

文2が要望を表している場合、要約は「AがBだから、Eに対してFをして欲しい」となります。この要約の作成にあたって、文1からは「AがBである」という部分を抽出し、文2からは「Eに対してFをして欲しい」という表現を抽出します。

AからFまでのそれぞれの項目は10文字以内である必要があり、接続詞や助詞は文字数に含めません。最終的な要約も含めて示してください。文2が規範的主張をしている場合は、EとFは「NA」であるとし、逆に文2が要望を表している場合は、CとDは「NA」であるとします。

エッジリストには元の文章に存在しないフレーズが含まれていないことを確認し、元の文章にないフレーズの出現回数が0であることを保証してください。

要約結果を以下のJSON形式で提供してください。説明文は含めずに、フォーマットのみを使用してください。可能な限り元の文の言葉を使用して下さい。最終的な要約文も示してください。

以下のJSON形式で答えてください。説明は入れず、このフォーマットのみで回答してください。
出力例：
{"種類"："規範的主張",
"A":"水星人の襲来",
"B":"世界にとって存亡の危機",
"C":"金星人との協力",
"D":"最優先事項",
"E":"NA",
"F":"NA",
"要約文":"水星人の襲来は世界にとって存亡の危機だから金星人との協力が最優先事項であるべきである。"}
=====
# %s"""

# %% [markdown]
# # Main

# %%
################################################
START_FROM_SCRATCH = 1
START_INDEX = 0
print(START_INDEX)
################################################

record2hantei = dict()
file_list = []

if START_FROM_SCRATCH != 1:
    for file in file_list:
        load_record(file,record2hantei)     
print(LOG_FILE)

# %%
# %%time
import time
for kkk in range(10):
    print("TRY: " + str(kkk) + ", Start " + str(START_INDEX))
    try:
        for i in tqdm.tqdm(range(START_INDEX,len(docs))):
            t =  docs[i]
            prompt = prompt_template_1 % t
            messages = [
                    {
                        "role" : "user",
                        "content" : prompt
                    }
            ]
            tmp_response_1 = get_completion(messages)
            num_tokens1, cost_dollar1, cost_yen1 = check_tokens(tmp_response_1, model)
            result = {
                    "index": doc_info[i][0],
                    "input": t,
                    "cost":{
                            1:{
                            "num_tokens1":num_tokens1,
                            "cost_dollar1":cost_dollar1,
                            "cost_yen1":cost_yen1
                        }
                    },
                    "answer":tmp_response_1
                }

            #### KOKODE HAKIDASU 
            with open(LOG_FILE, "a") as f:
                print(json.dumps(result), file=f)
            START_INDEX = i
                
    except:
        START_INDEX = i
        time.sleep(5.4)
# Out:
# TRY: 0, Start 0
#  78%|███████████████████████████▍       | 4698/6003 [8:33:05<2:22:31,  6.55s/it]
# TRY: 1, Start 4698
# 100%|█████████████████████████████████████| 1305/1305 [2:18:27<00:00,  6.37s/it]
# TRY: 2, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.45s/it]
# TRY: 3, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.78s/it]
# TRY: 4, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.62s/it]
# TRY: 5, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.77s/it]
# TRY: 6, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.50s/it]
# TRY: 7, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.53s/it]
# TRY: 8, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.35s/it]
# TRY: 9, Start 6002
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.21s/it]
# CPU times: user 1min 21s, sys: 6.01 s, total: 1min 27s
# Wall time: 10h 52min 14s
